# %%
import json
import datetime
import pandas as pd
from geopy import distance #will likely have to be installed separately

# %% [markdown]
# I started by finding the latitude and longitude boundaries of campus. I will draw a circular boundary from the midpoint of campus that should encompass all parts of campus with a bit of leeway. Even though this will extend slightly outside the range of campus it should be close enough since most of the extra area included is woods or streets I don't spend time on, so it shouldn't add extra data that isn't relevant. I used a website to help me locate where this circle is and its radius. I found a midpoint at: 38.990262, -76.943013 with a radium of 986.61 meters.

# %% [markdown]
# I started by finding the latitude and longitude boundaries campus, and the surrounding areas in College Park (basically from the apartments off of South Campus up north to where North Campus ends. And then far East enough to reach my home, and encompassing campas in the West). Using google maps I found that this area stretches over latitudes: 38.977086 to 39.000676 and it stretches over longitudes: -76.925135 to -76.953067. Since I plan to calculate travel times only in the campus area, I want to use only travel segments that start and end within these latitude and longitude ranges. We'll have to pick out these lat/long data from our JSON data that was downloaded from Google. <br>
# Using a JSON tree plugin for Notepad++ I got a good idea of how the data is organized. The top level of JSON is a single object named "timelineObjects." This contains an array of all the data collected by Google as a sequence of numbers. Each of these objects can be either a "placeVisit" or an "activitySegment." These two are basically interwoven with each other since each placeVisit is a location that a user ended a trip in, and each activitySegment represents a distance traveled by a user. <br>
# Each of these objects have their own elements. activitySegment has: startLocation, endLocation, duration, distance, activityType, confidence, activities, waypointPath, and simplifiedRawPath. Most of these are self-explanatory, but the remainder are actually simple as well. activity is the method of transportation (cycling, in_passenger_vehicle, train, etc.), confidence is how confident Google is that this method of transportation predicted is correct (can be HIGH, MEDIUM, etc.). activities contains the list of possible activities and the probability that Google thinks you were conducting this specific activity (essentially a further breakdown of 'activity'). waypointPath is the lat/long coordinates of each waypoint google has marked along your journey. simplifiedRawPath seems to be just waypointPath with less waypoints, but I'm not entirely sure what it represents. <br>
# placeVisit has elements: location, duration, placeConfidence, childVisits, visitConfidence, otherCandidateLocations, placeVisitType, and a few others. These are mostly self explanatory as well. placeConfidence is how likely Google thinks that the location given is correct (I assume this is done since GPS isn't hyper-accurate, so they try to predict exact location). childVisits is more local locations that may have been visited (like individual shops within a mall). placeVisitType is a value like SINGLE_PLACE. <br>
# Many of these attributes for activitySegment will be useful like startLocation, endLocation, duration, distance, acitvityType, and confidence. For placeVisit, I don't expect to need this data, however, it may turn out to be useful for determining which activitySegments ended on campus by checking of the placeVisit Location is a building on campus or campus itself

# %%
# create a list of all files using loops cuz I am lazy
months = ["JANUARY","FEBRUARY","MARCH","APRIL","MAY","JUNE","JULY","AUGUST","SEPTEMBER","OCTOBER","NOVEMBER","DECEMBER"]
years = ["2019_","2020_","2021_","2022_"]
fileList = []
for year in years:
    for month in months:
        fileList.append(f"{year}{month}")
# get rid of the extra files that account for months that are pre-August 2019, and post-May 2022    
fileList = fileList[7:41]
        
# Create a dataframe, and then append each file's data onto it by looping through them
# This takes a good 5 seconds on my PC
timelineData = pd.DataFrame()
for file in fileList:
    # Load the data in with loads() to be ready to convert to a dataframe
    with open(json_file,'r') as f:
        data_temp = json.loads(f.read())
    # Then use pd.json_normalize to flatten the data since it was in nested JSON object
    # record_path tells it where to look at data to normalize
    df_temp = pd.json_normalize(data, record_path = ['timelineObjects'])
    timelineData = pd.concat([timelineData, df_temp], ignore_index = True)
timelineData
# Out:
#        activitySegment.startLocation.latitudeE7  \
# 0                                   389961925.0
# 1                                           NaN
# 2                                   389860599.0
# 3                                           NaN
# 4                                   389959961.0
# ...                                         ...
# 10093                                       NaN
# 10094                               389868494.0
# 10095                                       NaN
# 10096                               389817136.0
# 10097                                       NaN
#
#        activitySegment.startLocation.longitudeE7  \
# 0                                   -769280436.0
# 1                                            NaN
# 2                                   -769469002.0
# 3                                            NaN
# 4                                   -769283521.0
# ...                                          ...
# 10093                                        NaN
# 10094                               -769415102.0
# 10095                                        NaN
# 10096                               -769404169.0
# 10097                                        NaN
#
#        activitySegment.startLocation.sourceInfo.deviceTag  \
# 0                                          -1.787875e+09
# 1                                                    NaN
# 2                                          -1.787875e+09
# 3                                                    NaN
# 4                                          -1.787875e+09
# ...                                                  ...
# 10093                                                NaN
# 10094                                      -1.787875e+09
# 10095                                                NaN
# 10096                                      -1.787875e+09
# 10097                                                NaN
#
#        activitySegment.endLocation.latitudeE7  \
# 0                                 389851415.0
# 1                                         NaN
# 2                                 389960539.0
# 3                                         NaN
# 4                                 389961894.0
# ...                                       ...
# 10093                                     NaN
# 10094                             389804719.0
# 10095                                     NaN
# 10096                             389961196.0
# 10097                                     NaN
#
#        activitySegment.endLocation.longitudeE7  \
# 0                                 -769475366.0
# 1                                          NaN
# 2                                 -769284190.0
# 3                                          NaN
# 4                                 -769285198.0
# ...                                        ...
# 10093                                      NaN
# 10094                             -769399685.0
# 10095                                      NaN
# 10096                             -769283715.0
# 10097                                      NaN
#
#        activitySegment.endLocation.sourceInfo.deviceTag  \
# 0                                         -1.787875e+09
# 1                                                   NaN
# 2                                         -1.787875e+09
# 3                                                   NaN
# 4                                         -1.787875e+09
# ...                                                 ...
# 10093                                               NaN
# 10094                                     -1.787875e+09
# 10095                                               NaN
# 10096                                     -1.787875e+09
# 10097                                               NaN
#
#       activitySegment.duration.startTimestamp  \
# 0                    2022-04-01T14:51:59.318Z
# 1                                         NaN
# 2                    2022-04-01T15:46:53.601Z
# 3                                         NaN
# 4                    2022-04-01T16:41:48.852Z
# ...                                       ...
# 10093                                     NaN
# 10094                2022-04-30T19:52:22.669Z
# 10095                                     NaN
# 10096                2022-04-30T23:45:48.903Z
# 10097                                     NaN
#
#       activitySegment.duration.endTimestamp  activitySegment.distance  \
# 0                  2022-04-01T15:07:35.066Z                    2133.0
# 1                                       NaN                       NaN
# 2                  2022-04-01T15:54:39.485Z                    2062.0
# 3                                       NaN                       NaN
# 4                  2022-04-01T17:01:58.680Z                    5889.0
# ...                                     ...                       ...
# 10093                                   NaN                       NaN
# 10094              2022-04-30T19:59:44.499Z                     756.0
# 10095                                   NaN                       NaN
# 10096              2022-04-30T23:52:56.976Z                    2035.0
# 10097                                   NaN                       NaN
#
#       activitySegment.activityType  ...  \
# 0                          CYCLING  ...
# 1                              NaN  ...
# 2                          CYCLING  ...
# 3                              NaN  ...
# 4             IN_PASSENGER_VEHICLE  ...
# ...                            ...  ...
# 10093                          NaN  ...
# 10094                      WALKING  ...
# 10095                          NaN  ...
# 10096         IN_PASSENGER_VEHICLE  ...
# 10097                          NaN  ...
#
#       activitySegment.simplifiedRawPath.source  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 10093                                      NaN
# 10094                                      NaN
# 10095                                      NaN
# 10096                                      NaN
# 10097                                      NaN
#
#       activitySegment.simplifiedRawPath.distanceMeters  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 10093                                              NaN
# 10094                                              NaN
# 10095                                              NaN
# 10096                                              NaN
# 10097                                              NaN
#
#       activitySegment.transitPath.transitStops  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 10093                                      NaN
# 10094                                      NaN
# 10095                                      NaN
# 10096                                      NaN
# 10097                                      NaN
#
#       activitySegment.transitPath.name  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 10093                              NaN
# 10094                              NaN
# 10095                              NaN
# 10096                              NaN
# 10097                              NaN
#
#       activitySegment.transitPath.hexRgbColor  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 10093                                     NaN
# 10094                                     NaN
# 10095                                     NaN
# 10096                                     NaN
# 10097                                     NaN
#
#        activitySegment.transitPath.linePlaceId  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 10093                                      NaN
# 10094                                      NaN
# 10095                                      NaN
# 10096                                      NaN
# 10097                                      NaN
#
#       activitySegment.transitPath.stopTimesInfo  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10093                                       NaN
# 10094                                       NaN
# 10095                                       NaN
# 10096                                       NaN
# 10097                                       NaN
#
#        activitySegment.transitPath.source  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 10093                                 NaN
# 10094                                 NaN
# 10095                                 NaN
# 10096                                 NaN
# 10097                                 NaN
#
#       activitySegment.transitPath.confidence  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 10093                                    NaN
# 10094                                    NaN
# 10095                                    NaN
# 10096                                    NaN
# 10097                                    NaN
#
#        activitySegment.transitPath.distanceMeters
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 10093                                         NaN
# 10094                                         NaN
# 10095                                         NaN
# 10096                                         NaN
# 10097                                         NaN
#
# [10098 rows x 59 columns]

# %% [markdown]
# This data obviously needs a lot of clean-up. I saw some libraries like Glom that could've been used to extract data more nicely, but since I only need a few attributes it's simple enough to just clean up the data after putting it in the dataframe.

# %%
# Start by dropping all of the placeVisits by getting rid of rows that don't have data in activitySegment columns
timelineData.dropna(subset=['activitySegment.startLocation.latitudeE7'],inplace=True)

# Next include only the columns we actually care about
timelineDataClean = timelineData[timelineData.columns[[0,1,3,4,6,7,8,9,10]]]

# Finally let's rename these columns
timelineDataClean.set_axis(['startLat', 'startLng', 'endLat', 'endLng', 'startTime', 'endTime', 'dist', 'activity', 'confidence'], axis=1, inplace=True)
timelineDataClean
# Out:
#           startLat     startLng       endLat       endLng  \
# 0      389961925.0 -769280436.0  389851415.0 -769475366.0
# 2      389860599.0 -769469002.0  389960539.0 -769284190.0
# 4      389959961.0 -769283521.0  389961894.0 -769285198.0
# 6      389962056.0 -769287358.0  389881245.0 -769398750.0
# 8      389885651.0 -769401921.0  389960442.0 -769284344.0
# ...            ...          ...          ...          ...
# 10088  389828505.0 -769480967.0  389839017.0 -769485749.0
# 10090  389855996.0 -769489810.0  389959959.0 -769284153.0
# 10092  389961471.0 -769287037.0  389867376.0 -769413156.0
# 10094  389868494.0 -769415102.0  389804719.0 -769399685.0
# 10096  389817136.0 -769404169.0  389961196.0 -769283715.0
#
#                       startTime                   endTime    dist  \
# 0      2022-04-01T14:51:59.318Z  2022-04-01T15:07:35.066Z  2133.0
# 2      2022-04-01T15:46:53.601Z  2022-04-01T15:54:39.485Z  2062.0
# 4      2022-04-01T16:41:48.852Z  2022-04-01T17:01:58.680Z  5889.0
# 6      2022-04-01T17:56:50.999Z  2022-04-01T18:01:47.945Z  1429.0
# 8      2022-04-01T18:41:11.296Z  2022-04-01T18:52:59.762Z  1313.0
# ...                         ...                       ...     ...
# 10088  2022-04-30T00:49:22.391Z  2022-04-30T00:50:23.606Z   134.0
# 10090  2022-04-30T04:03:03.492Z  2022-04-30T04:08:46.399Z  2757.0
# 10092      2022-04-30T13:22:57Z  2022-04-30T13:27:44.879Z  1729.0
# 10094  2022-04-30T19:52:22.669Z  2022-04-30T19:59:44.499Z   756.0
# 10096  2022-04-30T23:45:48.903Z  2022-04-30T23:52:56.976Z  2035.0
#
#                    activity confidence
# 0                   CYCLING       HIGH
# 2                   CYCLING       HIGH
# 4      IN_PASSENGER_VEHICLE     MEDIUM
# 6                   CYCLING     MEDIUM
# 8                   CYCLING     MEDIUM
# ...                     ...        ...
# 10088               WALKING       HIGH
# 10090  IN_PASSENGER_VEHICLE       HIGH
# 10092               CYCLING       HIGH
# 10094               WALKING        LOW
# 10096  IN_PASSENGER_VEHICLE     MEDIUM
#
# [5066 rows x 9 columns]

# %% [markdown]
# Now that we've got our data cleaned up, we can start filtering it to ensure that we're only including data that takes place around UMD campus. In addition I'm going to drop any LOW confidence activities since Google doesn't display these in my account's timeline history. I don't believe that dropping these datapoints should skew the data since I expect the low confidence is due to bad GPS data, not due to any factors I plan to analyze such as duration or distance.

# %%
# First let's ensure we only look at start and end locations that are on the campus
# This means filtering by latitudes between 38.977086 to 39.000676 and longitudes between -76.925135 to -76.953067
# These coordinates are represented without a decimal point though, so in reality we need to multiply these numbers by 10^7

criterian = (timelineDataClean['startLat'] < 390000676) & (timelineDataClean['startLat'] > 389770860)
criterian = criterian & (timelineDataClean['endLat'] < 390000676) & (timelineDataClean['endLat'] > 389770860)
criterian = criterian & (timelineDataClean['startLng'] < -769251350) & (timelineDataClean['startLng'] > -769530670)
criterian = criterian & (timelineDataClean['endLng'] < -769251350) & (timelineDataClean['endLng'] > -769530670)

# We also only want activitySegments where the confidence level is at least MEDIUM
criterian = criterian & ( (timelineDataClean['confidence'] == "MEDIUM") | (timelineDataClean['confidence'] == "HIGH") )

finalData = timelineDataClean[criterian]
finalData
#timelineDataClean[[(x == "LOW") for x in timelineDataClean['confidence']]]
# Out:
#           startLat     startLng       endLat       endLng  \
# 0      389961925.0 -769280436.0  389851415.0 -769475366.0
# 2      389860599.0 -769469002.0  389960539.0 -769284190.0
# 4      389959961.0 -769283521.0  389961894.0 -769285198.0
# 6      389962056.0 -769287358.0  389881245.0 -769398750.0
# 8      389885651.0 -769401921.0  389960442.0 -769284344.0
# ...            ...          ...          ...          ...
# 10084  389867763.0 -769412799.0  389960635.0 -769284629.0
# 10088  389828505.0 -769480967.0  389839017.0 -769485749.0
# 10090  389855996.0 -769489810.0  389959959.0 -769284153.0
# 10092  389961471.0 -769287037.0  389867376.0 -769413156.0
# 10096  389817136.0 -769404169.0  389961196.0 -769283715.0
#
#                       startTime                   endTime    dist  \
# 0      2022-04-01T14:51:59.318Z  2022-04-01T15:07:35.066Z  2133.0
# 2      2022-04-01T15:46:53.601Z  2022-04-01T15:54:39.485Z  2062.0
# 4      2022-04-01T16:41:48.852Z  2022-04-01T17:01:58.680Z  5889.0
# 6      2022-04-01T17:56:50.999Z  2022-04-01T18:01:47.945Z  1429.0
# 8      2022-04-01T18:41:11.296Z  2022-04-01T18:52:59.762Z  1313.0
# ...                         ...                       ...     ...
# 10084  2022-04-29T23:17:29.962Z  2022-04-29T23:22:57.123Z  1653.0
# 10088  2022-04-30T00:49:22.391Z  2022-04-30T00:50:23.606Z   134.0
# 10090  2022-04-30T04:03:03.492Z  2022-04-30T04:08:46.399Z  2757.0
# 10092      2022-04-30T13:22:57Z  2022-04-30T13:27:44.879Z  1729.0
# 10096  2022-04-30T23:45:48.903Z  2022-04-30T23:52:56.976Z  2035.0
#
#                    activity confidence
# 0                   CYCLING       HIGH
# 2                   CYCLING       HIGH
# 4      IN_PASSENGER_VEHICLE     MEDIUM
# 6                   CYCLING     MEDIUM
# 8                   CYCLING     MEDIUM
# ...                     ...        ...
# 10084  IN_PASSENGER_VEHICLE     MEDIUM
# 10088               WALKING       HIGH
# 10090  IN_PASSENGER_VEHICLE       HIGH
# 10092               CYCLING       HIGH
# 10096  IN_PASSENGER_VEHICLE     MEDIUM
#
# [3060 rows x 9 columns]

# %%
cycling = finalData[finalData['activity'] == "CYCLING"]
driving = finalData[finalData['activity'] == "IN_PASSENGER_VEHICLE"]
walking = finalData[finalData['activity'] == "WALKING"]
print(cycling.count())
print(driving.count())
print(walking.count())
# Out:
# startLat      1768
# startLng      1768
# endLat        1768
# endLng        1768
# startTime     1768
# endTime       1768
# dist          1768
# activity      1768
# confidence    1768
# dtype: int64
# startLat      1156
# startLng      1156
# endLat        1156
# endLng        1156
# startTime     1156
# endTime       1156
# dist          1156
# activity      1156
# confidence    1156
# dtype: int64
# startLat      136
# startLng      136
# endLat        136
# endLng        136
# startTime     136
# endTime       136
# dist          136
# activity      136
# confidence    136
# dtype: int64

# %% [markdown]
# break cell:

# %%
#all of the below taken from: https://medium.com/@stephen.hogg.sh/interrogating-googles-timeline-data-ca22c3a9fd2c
start_year, start_month, start_day = 2019, 8, 22
end_year, end_month, end_day = 2022, 5, 7
point_of_interest = (38.9869, -76.9426)  # Latitude, Longitude
distance_from_point_of_interest = 0.986 # km of distance
aggregate_by = 'Day'   # This can be 'Year', 'Month', 'Day', 'Hour', 'Second'
# weekday_exceptions = ['Saturday','Sunday'] # A list of weekdays that should excluded.

# Reformat the start/end datetimes to epoch times in milliseconds
start_datetime = datetime.datetime(start_year,start_month,start_day).timestamp()*1e3
end_datetime = datetime.datetime(end_year,end_month,end_day).timestamp()*1e3

# Setup the aggregate list
aggregate_options = ['Year','Month','Day','Hour','Second']
aggregate_list = aggregate_options[:aggregate_options.index(aggregate_by)+1]

# %%
# We'll start with just April 2022 data to test out the timeline data
json_file = "2022_APRIL.json"
data = json.load(open(json_file))   # Read the file
# locations = data['locations']

# %%
data
# Out:
# {'timelineObjects': [{'activitySegment': {'startLocation': {'latitudeE7': 389961925,
#      'longitudeE7': -769280436,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'endLocation': {'latitudeE7': 389851415,
#      'longitudeE7': -769475366,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'duration': {'startTimestamp': '2022-04-01T14:51:59.318Z',
#      'endTimestamp': '2022-04-01T15:07:35.066Z'},
#     'distance': 2133,
#     'activityType': 'CYCLING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'CYCLING',
#       'probability': 78.75603437423706},
#      {'activityType': 'IN_PASSENGER_VEHICLE', 'probability': 9.31272879242897},
#      {'activityType': 'WALKING', 'probability': 5.101209878921509},
#      {'activityType': 'MOTORCYCLING', 'probability': 3.6667339503765106},
#      {'activityType': 'STILL', 'probability': 1.1762714013457298},
#      {'activityType': 'IN_BUS', 'probability': 1.0320750065147877},
#      {'activityType': 'IN_TRAIN', 'probability': 0.40568551048636436},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.23049537558108568},
#      {'activityType': 'RUNNING', 'probability': 0.1373813720420003},
#      {'activityType': 'IN_FERRY', 'probability': 0.09455176768824458},
#      {'activityType': 'IN_TRAM', 'probability': 0.05882972036488354},
#      {'activityType': 'SKIING', 'probability': 0.018956512212753296},
#      {'activityType': 'SAILING', 'probability': 0.008395475742872804},
#      {'activityType': 'FLYING', 'probability': 0.0006557061169587541},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.2302957763665745e-06}],
#     'waypointPath': {'waypoints': [{'latE7': 389960670, 'lngE7': -769280853},
#       {'latE7': 389899368, 'lngE7': -769352188},
#       {'latE7': 389880485, 'lngE7': -769430541},
#       {'latE7': 389875221, 'lngE7': -769445190},
#       {'latE7': 389875144, 'lngE7': -769447402},
#       {'latE7': 389863510, 'lngE7': -769476547},
#       {'latE7': 389855880, 'lngE7': -769470825}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJ7dSrIqjGt4kR_q3lWB_SHdM',
#        'duration': '33s'},
#       {'placeId': 'ChIJ9cMLBajGt4kRlFOm-MEW6Tk', 'duration': '23s'},
#       {'placeId': 'ChIJ2RWPB6jGt4kRsZtdewnBSY0', 'duration': '19s'},
#       {'placeId': 'ChIJs5fp46fGt4kR4Ub5I215MEA', 'duration': '27s'},
#       {'placeId': 'ChIJbY9gwqfGt4kRlE_WO_tcBr0', 'duration': '7s'},
#       {'placeId': 'ChIJbY9gwqfGt4kReWTzg_fIjLw', 'duration': '13s'},
#       {'placeId': 'ChIJtT30vqfGt4kR4EzxPMxyEok', 'duration': '7s'},
#       {'placeId': 'ChIJoxD7vKfGt4kRsCeFFbRjXOM', 'duration': '3s'},
#       {'placeId': 'ChIJYR60pKfGt4kRMscL5m5kl7s', 'duration': '5s'},
#       {'placeId': 'ChIJYSiOr6fGt4kRvriW0HUqRao', 'duration': '3s'},
#       {'placeId': 'ChIJvf70rqfGt4kR1uYANS8RYVo', 'duration': '1s'},
#       {'placeId': 'ChIJRRc8rKfGt4kRpgC1yl5mNmE', 'duration': '1s'},
#       {'placeId': 'ChIJlaWPrKfGt4kRBu7vqm0N190', 'duration': '1s'},
#       {'placeId': 'ChIJg3ymrKfGt4kR7pchIooSP2A', 'duration': '1s'},
#       {'placeId': 'ChIJcYCiVKbGt4kRK4a90oiPDq8', 'duration': '1s'},
#       {'placeId': 'ChIJf90-VKbGt4kRHbCV2Iv6vTA', 'duration': '1s'},
#       {'placeId': 'ChIJqeaLVqbGt4kRh77UUSy6YP8', 'duration': '0s'},
#       {'placeId': 'ChIJATS7V6bGt4kRz1IqeckXWaw', 'duration': '3s'},
#       {'placeId': 'ChIJYx1uWKbGt4kRrfX9qySzPII', 'duration': '3s'},
#       {'placeId': 'ChIJF8YF9qbGt4kRq-xOw6ChBes', 'duration': '3s'},
#       {'placeId': 'ChIJU4699abGt4kRV37TFocxO94', 'duration': '1s'},
#       {'placeId': 'ChIJwykP9abGt4kR2eDPQTwsrN0', 'duration': '0s'},
#       {'placeId': 'ChIJUZgQi6bGt4kRFhuy0jpRl7k', 'duration': '13s'},
#       {'placeId': 'ChIJNe4lj6bGt4kRSMD5JZmGgP8', 'duration': '11s'},
#       {'placeId': 'ChIJBa6VhabGt4kRefoAESd3IRg', 'duration': '5s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRSua6zVKChfQ', 'duration': '1s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRKSCI3Arn_O4', 'duration': '9s'},
#       {'placeId': 'ChIJUVexgqbGt4kREYow6lIg9I8', 'duration': '0s'},
#       {'placeId': 'ChIJ1eP_J6TGt4kRC85_1nga4gY', 'duration': '0s'},
#       {'placeId': 'ChIJgTLMJ6TGt4kR9vdEU_Jy5P4', 'duration': '1s'},
#       {'placeId': 'ChIJ54VqJqTGt4kR6svpTnpad6Y', 'duration': '1s'},
#       {'placeId': 'ChIJKR_YJaTGt4kR7DjkDdbWGgQ', 'duration': '1s'},
#       {'placeId': 'ChIJKR_YJaTGt4kRZZ_4-RmSFbA', 'duration': '0s'},
#       {'placeId': 'ChIJ15nDJKTGt4kRwI5PgVPH0bs', 'duration': '9s'},
#       {'placeId': 'ChIJBXXnPqTGt4kRKkwbu7JTb8c', 'duration': '5s'},
#       {'placeId': 'ChIJBXXnPqTGt4kR4SXMectGJxE', 'duration': '11s'},
#       {'placeId': 'ChIJB_tMQKTGt4kRilHprYUbYEc', 'duration': '1s'},
#       {'placeId': 'ChIJhbB2aqTGt4kR9f6WgmO8Gug', 'duration': '5s'},
#       {'placeId': 'ChIJo7YCb6TGt4kRDXRxrow9uak', 'duration': '5s'},
#       {'placeId': 'ChIJo7YCb6TGt4kRYEVClhUPAwU', 'duration': '15s'},
#       {'placeId': 'ChIJZ16SeqTGt4kRBsMYSTAbkPg', 'duration': '17s'},
#       {'placeId': 'ChIJH5PufaTGt4kRPeTwcBsXWTE', 'duration': '13s'},
#       {'placeId': 'ChIJLVKfhqTGt4kRKrM5POmgqb4', 'duration': '15s'},
#       {'placeId': 'ChIJURpknaTGt4kRI5ZtGT5Ag0A', 'duration': '3s'},
#       {'placeId': 'ChIJURpknaTGt4kRxPvBGmz9iBo', 'duration': '25s'},
#       {'placeId': 'ChIJ-01gfaPGt4kRq9U2bLivtBQ', 'duration': '0s'},
#       {'placeId': 'ChIJi3reZqPGt4kRU2AGTwS1-Ys', 'duration': '31s'},
#       {'placeId': 'ChIJvzHZP6PGt4kRa9WbOir-_GQ', 'duration': '23s'},
#       {'placeId': 'ChIJ739GJKPGt4kRibBz0QooUPs', 'duration': '37s'},
#       {'placeId': 'ChIJP1s316LGt4kRm4fgkOZi4lo', 'duration': '13s'},
#       {'placeId': 'ChIJf3m60aLGt4kRWayUpoJAirY', 'duration': '3s'},
#       {'placeId': 'ChIJ72GhzqLGt4kRH9VVyhsECWI', 'duration': '27s'},
#       {'placeId': 'ChIJxUIbyqLGt4kRCxHtyOUj7ow', 'duration': '0s'},
#       {'placeId': 'ChIJBcfPtaLGt4kR7xMbg0K8Xxk', 'duration': '17s'},
#       {'placeId': 'ChIJAe0NtKLGt4kRj7vhY0T52r0', 'duration': '0s'},
#       {'placeId': 'ChIJcec2sqLGt4kR3S8SnW3LGgY', 'duration': '23s'},
#       {'placeId': 'ChIJt5CVrKLGt4kRD-ikJtyFgIE', 'duration': '35s'},
#       {'placeId': 'ChIJh1UaVb3Gt4kRHyFSxOVtZbM', 'duration': '15s'},
#       {'placeId': 'ChIJlT-DVb3Gt4kR_wpgKCMB7XA', 'duration': '0s'},
#       {'placeId': 'ChIJ21A9_pfGt4kR0kHckPHHxpM', 'duration': '11s'},
#       {'placeId': 'ChIJL1dX-ZfGt4kR6R68TxQS0jc', 'duration': '33s'},
#       {'placeId': 'ChIJ4y-P9pfGt4kRW1WHAM2KFTQ', 'duration': '21s'},
#       {'placeId': 'ChIJEbfyipfGt4kRyNDrUrYaHlA', 'duration': '21s'},
#       {'placeId': 'ChIJHwD9i5fGt4kRUc-NO0MGFmk', 'duration': '40s'},
#       {'placeId': 'ChIJ1Z3ejZfGt4kR79-BqiHCorQ', 'duration': '5s'},
#       {'placeId': 'ChIJVzIcjpfGt4kRZ1uUKK54wzw', 'duration': '9s'},
#       {'placeId': 'ChIJNWwhkJfGt4kR4wAPlLgXEew', 'duration': '13s'},
#       {'placeId': 'ChIJH0k7m5fGt4kRkz1jcOEs2M0', 'duration': '27s'},
#       {'placeId': 'ChIJK5QTnZfGt4kRkSuw_yqwbeA', 'duration': '15s'},
#       {'placeId': 'ChIJNcW2d5fGt4kRE3iLYRPHRvM', 'duration': '1s'},
#       {'placeId': 'ChIJayricZfGt4kRc2Iat9BkrDU', 'duration': '44s'},
#       {'placeId': 'ChIJ6zZJQJfGt4kR0m2zKT33JhU', 'duration': '15s'},
#       {'placeId': 'ChIJByubOJfGt4kRjcFpcWQs0lk', 'duration': '1s'},
#       {'placeId': 'ChIJhejxN5fGt4kR1SVuWeZco4Y', 'duration': '9s'},
#       {'placeId': 'ChIJi-PANZfGt4kROWrbVPnpkxA', 'duration': '9s'},
#       {'placeId': 'ChIJOSzfypDGt4kRznZb0P6OpHc', 'duration': '5s'},
#       {'placeId': 'ChIJo3XKy5DGt4kRKh_0I-jXDfM', 'duration': '1s'},
#       {'placeId': 'ChIJsYJxyZDGt4kRRhBgr4BMCGA', 'duration': '1s'},
#       {'placeId': 'ChIJS1nuyJDGt4kRTtRNUI1zgwA', 'duration': '1s'},
#       {'placeId': 'ChIJQZH6z5DGt4kRg5kfg_PgrfE', 'duration': '25s'},
#       {'placeId': 'ChIJoclu15DGt4kR_cbc0jEGgKk', 'duration': '3s'},
#       {'placeId': 'ChIJST_g15DGt4kR-cKmohH0HMI', 'duration': '7s'},
#       {'placeId': 'ChIJ2SEcKZHGt4kRzvc3SYaahFE', 'duration': '7s'},
#       {'placeId': 'ChIJO9agLpHGt4kRFIqCBbtj3Z0', 'duration': '5s'},
#       {'placeId': 'ChIJiwzaLZHGt4kRSK-YVMasnGU', 'duration': '1s'},
#       {'placeId': 'ChIJ8UQbLZHGt4kR6J7N7beeI-M', 'duration': '3s'}],
#      'distanceMeters': 2706.6250948471707,
#      'travelMode': 'BICYCLE',
#      'confidence': 1.0},
#     'simplifiedRawPath': {'points': [{'latE7': 389880409,
#        'lngE7': -769430542,
#        'accuracyMeters': 18,
#        'timestamp': '2022-04-01T14:58:57.597Z'},
#       {'latE7': 389874496,
#        'lngE7': -769447327,
#        'accuracyMeters': 35,
#        'timestamp': '2022-04-01T14:59:38.788Z'}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 389869183,
#      'longitudeE7': -769425543,
#      'placeId': 'ChIJq6qaPr3Gt4kRmtrkpd2LjtQ',
#      'address': 'College Park, MD 20742\nUSA',
#      'name': 'University of Maryland',
#      'sourceInfo': {'deviceTag': -1787875010},
#      'locationConfidence': 83.969826,
#      'calibratedProbability': 76.07613},
#     'duration': {'startTimestamp': '2022-04-01T15:07:35.066Z',
#      'endTimestamp': '2022-04-01T15:46:53.601Z'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'childVisits': [{'location': {'latitudeE7': 389850486,
#        'longitudeE7': -769475700,
#        'placeId': 'ChIJwfjFLJHGt4kRMJ1ZF0cWUeY',
#        'address': '3834 Campus Dr\nCollege Park, MD 20740\nUSA',
#        'name': 'Parren J Mitchell Art Sociology',
#        'sourceInfo': {'deviceTag': -1787875010},
#        'locationConfidence': 31.662336,
#        'calibratedProbability': 40.704742},
#       'duration': {'startTimestamp': '2022-04-01T15:07:35.066Z',
#        'endTimestamp': '2022-04-01T15:46:53.601Z'},
#       'placeConfidence': 'LOW_CONFIDENCE',
#       'centerLatE7': 389851785,
#       'centerLngE7': -769474880,
#       'visitConfidence': 95,
#       'otherCandidateLocations': [{'latitudeE7': 389853283,
#         'longitudeE7': -769494348,
#         'placeId': 'ChIJk3UjDJHGt4kR9VcWuW35i90',
#         'address': 'College Park, MD 20742\nUSA',
#         'name': 'UMD',
#         'locationConfidence': 15.639111,
#         'calibratedProbability': 20.105463},
#        {'latitudeE7': 389859692,
#         'longitudeE7': -769467948,
#         'placeId': 'ChIJTYSQ1ZbGt4kRBr_mb-GfzPg',
#         'address': '3915 Campus Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'Anne Arundel Hall',
#         'locationConfidence': 4.9091177,
#         'calibratedProbability': 6.311106},
#        {'latitudeE7': 389859487,
#         'longitudeE7': -769485837,
#         'placeId': 'ChIJI_2vJpHGt4kRx_xWKcXEsQw',
#         'address': '7751 Alumni Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'Tawes Hall',
#         'locationConfidence': 3.4152126,
#         'calibratedProbability': 4.3905587},
#        {'latitudeE7': 389851345,
#         'longitudeE7': -769477726,
#         'placeId': 'ChIJ__8_MZHGt4kRaFPoAm9wMN4',
#         'address': '2202\nParren J. Mitchell Art-Sociology Building\n3834 Campus Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'University of Maryland Art Gallery',
#         'locationConfidence': 3.3983977,
#         'calibratedProbability': 4.368942},
#        {'latitudeE7': 389841865,
#         'longitudeE7': -769492407,
#         'placeId': 'ChIJdb1IkJHGt4kRuCc-tJjjOsw',
#         'address': '3711 Campus Dr\nCollege Park, MD 20740\nUSA',
#         'name': 'Domain College Park',
#         'locationConfidence': 2.5687222,
#         'calibratedProbability': 3.3023202},
#        {'latitudeE7': 389831658,
#         'longitudeE7': -769457691,
#         'placeId': 'ChIJzTTy6pfGt4kRhag_JtKh8Xo',
#         'address': '7030 Preinkert Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'Prince Frederick Hall',
#         'locationConfidence': 2.3244596,
#         'calibratedProbability': 2.988299},
#        {'latitudeE7': 389851578,
#         'longitudeE7': -769475233,
#         'placeId': 'ChIJo8EtMZHGt4kRVorLMxkwOlY',
#         'address': '2112 Parren Mitchell Art-Sociology Building\n3834 Campus Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'Department of Sociology',
#         'locationConfidence': 1.9918445,
#         'calibratedProbability': 2.5606928},
#        {'latitudeE7': 389873420,
#         'longitudeE7': -769446406,
#         'placeId': 'ChIJJ9TSLgfHt4kROJDj3I8ietQ',
#         'address': '140 Campus Dr\nCollege Park, MD 20740\nUSA',
#         'name': 'University Of Maryland Health Center',
#         'locationConfidence': 0.8634127,
#         'calibratedProbability': 1.1099936},
#        {'latitudeE7': 389860033,
#         'longitudeE7': -769424154,
#         'placeId': 'ChIJIZXUyJfGt4kRbRXCzztx0DY',
#         'address': '7998 Regents Dr\nCollege Park, MD 20742\nUSA',
#         'name': 'McKeldin Mall',
#         'locationConfidence': 0.83931637,
#         'calibratedProbability': 1.0790156}],
#       'editConfirmationStatus': 'NOT_CONFIRMED',
#       'locationConfidence': 25,
#       'placeVisitType': 'SINGLE_PLACE',
#       'placeVisitLevel': 1}],
#     'centerLatE7': 389851785,
#     'centerLngE7': -769474880,
#     'visitConfidence': 95,
#     'otherCandidateLocations': [{'latitudeE7': 389841865,
#       'longitudeE7': -769492407,
#       'placeId': 'ChIJdb1IkJHGt4kRuCc-tJjjOsw',
#       'address': '3711 Campus Dr\nCollege Park, MD 20740\nUSA',
#       'name': 'Domain College Park',
#       'locationConfidence': 7.421957,
#       'calibratedProbability': 6.7242465},
#      {'latitudeE7': 389858170,
#       'longitudeE7': -769480820,
#       'placeId': 'ChIJ6XkxPpfGt4kRmp0eZSOaMAc',
#       'address': "St Mary's Hall\n3949 Campus Dr\nCollege Park, MD 20742\nUSA",
#       'name': "St. Mary's Hall",
#       'locationConfidence': 3.1424363,
#       'calibratedProbability': 2.8470275},
#      {'latitudeE7': 389827510,
#       'longitudeE7': -769486330,
#       'placeId': 'ChIJYV5v75PGt4kRndh4gd8RWKA',
#       'address': '7612 Mowatt Ln\nCollege Park, MD 20740\nUSA',
#       'name': 'University of Maryland Hillel',
#       'locationConfidence': 0.7502243,
#       'calibratedProbability': 0.6796985},
#      {'latitudeE7': 389830569,
#       'longitudeE7': -769470575,
#       'placeId': 'ChIJ6b3N-5PGt4kRpqigwAQlDtA',
#       'address': 'Van Munching Hall\n7699 Mowatt Ln\nCollege Park, MD 20742\nUSA',
#       'name': 'Van Munching Hall',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 0.6556587,
#       'calibratedProbability': 0.5940227}],
#     'editConfirmationStatus': 'NOT_CONFIRMED',
#     'simplifiedRawPath': {'points': [{'latE7': 389851415,
#        'lngE7': -769475366,
#        'accuracyMeters': 16,
#        'timestamp': '2022-04-01T15:07:35.066Z'},
#       {'latE7': 389852999,
#        'lngE7': -769473753,
#        'accuracyMeters': 13,
#        'timestamp': '2022-04-01T15:45:50.155Z'}],
#      'source': 'INFERRED',
#      'distanceMeters': 22.16829092836278},
#     'locationConfidence': 68,
#     'placeVisitType': 'SINGLE_PLACE',
#     'placeVisitImportance': 'MAIN'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 389860599,
#      'longitudeE7': -769469002,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'endLocation': {'latitudeE7': 389960539,
#      'longitudeE7': -769284190,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'duration': {'startTimestamp': '2022-04-01T15:46:53.601Z',
#      'endTimestamp': '2022-04-01T15:54:39.485Z'},
#     'distance': 2062,
#     'activityType': 'CYCLING',
#     'confidence': 'HIGH',
#     'activities': [{'activityType': 'CYCLING',
#       'probability': 83.49824547767639},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 9.252151101827621},
#      {'activityType': 'WALKING', 'probability': 3.550513833761215},
#      {'activityType': 'MOTORCYCLING', 'probability': 2.7329221367836},
#      {'activityType': 'STILL', 'probability': 0.33623825293034315},
#      {'activityType': 'IN_BUS', 'probability': 0.3206216963008046},
#      {'activityType': 'RUNNING', 'probability': 0.1655719825066626},
#      {'activityType': 'IN_FERRY', 'probability': 0.04397178126964718},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.03205271204933524},
#      {'activityType': 'IN_TRAIN', 'probability': 0.030376302311196923},
#      {'activityType': 'SKIING', 'probability': 0.023100234102457762},
#      {'activityType': 'SAILING', 'probability': 0.007298676064237952},
#      {'activityType': 'IN_TRAM', 'probability': 0.006758805830031633},
#      {'activityType': 'FLYING', 'probability': 0.0001707018327579135},
#      {'activityType': 'IN_VEHICLE', 'probability': 5.238988687317203e-08}],
#     'waypointPath': {'waypoints': [{'latE7': 389860649, 'lngE7': -769469833},
#       {'latE7': 389865722, 'lngE7': -769450149},
#       {'latE7': 389875221, 'lngE7': -769442977},
#       {'latE7': 389899368, 'lngE7': -769352188},
#       {'latE7': 389927940, 'lngE7': -769332046},
#       {'latE7': 389923782, 'lngE7': -769325485},
#       {'latE7': 389961280, 'lngE7': -769283981}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJRZdY1ZbGt4kRXgxM4x8MHjg',
#        'duration': '3s'},
#       {'placeId': 'ChIJl3SBK5fGt4kRHXZ0BgyKH5Y', 'duration': '2s'},
#       {'placeId': 'ChIJw2eYLpfGt4kR8fsT-xrw8Uk', 'duration': '1s'},
#       {'placeId': 'ChIJ-X2qL5fGt4kRy33T9D4MkVA', 'duration': '1s'},
#       {'placeId': 'ChIJsSCPL5fGt4kRPSftQGzPsSg', 'duration': '1s'},
#       {'placeId': 'ChIJIVC_JJfGt4kRJSr28G40Bg0', 'duration': '3s'},
#       {'placeId': 'ChIJzyK1IpfGt4kRswi-39JhXSA', 'duration': '2s'},
#       {'placeId': 'ChIJoSlpF5fGt4kRdXc0qlroJAY', 'duration': '3s'},
#       {'placeId': 'ChIJZ_NbEJfGt4kRC3EEEMFChhs', 'duration': '1s'},
#       {'placeId': 'ChIJi57RD5fGt4kRWUzrAeGogoY', 'duration': '1s'},
#       {'placeId': 'ChIJP5aqD5fGt4kRajKq2p557AE', 'duration': '0s'},
#       {'placeId': 'ChIJ1SDfDpfGt4kRefNBcfbW_W8', 'duration': '1s'},
#       {'placeId': 'ChIJwU8XCZfGt4kRFb17jO9cq-U', 'duration': '3s'},
#       {'placeId': 'ChIJ5_aRCZfGt4kRUwH93of1PIo', 'duration': '2s'},
#       {'placeId': 'ChIJ3-brCpfGt4kR06SeNYNsFPM', 'duration': '12s'},
#       {'placeId': 'ChIJE1rFdZfGt4kRH8_45WI13FI', 'duration': '15s'},
#       {'placeId': 'ChIJcRmid5fGt4kRbUaF1UHPu2E', 'duration': '1s'},
#       {'placeId': 'ChIJm8EQeJfGt4kR36CnhLqlPls', 'duration': '2s'},
#       {'placeId': 'ChIJSU9NgJfGt4kRB5ETbBRR49Q', 'duration': '12s'},
#       {'placeId': 'ChIJGWrbK5jGt4kRA2LoFlZFYww', 'duration': '1s'},
#       {'placeId': 'ChIJ7de-KJjGt4kRRJocOq7BBzs', 'duration': '5s'},
#       {'placeId': 'ChIJeQGcJpjGt4kRNIdotlLiH30', 'duration': '3s'},
#       {'placeId': 'ChIJa8ZSIJjGt4kRNek0bLm_pXU', 'duration': '5s'},
#       {'placeId': 'ChIJF5Zd9ZfGt4kRJ99KSkpxpig', 'duration': '0s'},
#       {'placeId': 'ChIJ4y-P9pfGt4kRWlWHAM2KFTQ', 'duration': '9s'},
#       {'placeId': 'ChIJL1dX-ZfGt4kR6B68TxQS0jc', 'duration': '4s'},
#       {'placeId': 'ChIJ21A9_pfGt4kR00HckPHHxpM', 'duration': '1s'},
#       {'placeId': 'ChIJlT-DVb3Gt4kR_gpgKCMB7XA', 'duration': '0s'},
#       {'placeId': 'ChIJh1UaVb3Gt4kRHiFSxOVtZbM', 'duration': '1s'},
#       {'placeId': 'ChIJt5CVrKLGt4kRDuikJtyFgIE', 'duration': '5s'},
#       {'placeId': 'ChIJcec2sqLGt4kR3C8SnW3LGgY', 'duration': '3s'},
#       {'placeId': 'ChIJAe0NtKLGt4kRjrvhY0T52r0', 'duration': '0s'},
#       {'placeId': 'ChIJ25lEtKLGt4kR9M0-ryLrsk8', 'duration': '1s'},
#       {'placeId': 'ChIJTe0VtaLGt4kREBH2NxPKWMA', 'duration': '2s'},
#       {'placeId': 'ChIJFShTNb3Gt4kRpPX37Sn9XC4', 'duration': '0s'},
#       {'placeId': 'ChIJAd0zNb3Gt4kRXt04jk9mdng', 'duration': '0s'},
#       {'placeId': 'ChIJQyjLNL3Gt4kRbpAv3I452DE', 'duration': '1s'},
#       {'placeId': 'ChIJa6cZzaLGt4kRHKu3_rmaOMI', 'duration': '3s'},
#       {'placeId': 'ChIJNxJM0aLGt4kR3oj_--NW_xs', 'duration': '5s'},
#       {'placeId': 'ChIJ739GJKPGt4kRiLBz0QooUPs', 'duration': '12s'},
#       {'placeId': 'ChIJvzHZP6PGt4kRatWbOir-_GQ', 'duration': '5s'},
#       {'placeId': 'ChIJi3reZqPGt4kRUmAGTwS1-Ys', 'duration': '6s'},
#       {'placeId': 'ChIJ-01gfaPGt4kRqtU2bLivtBQ', 'duration': '0s'},
#       {'placeId': 'ChIJURpknaTGt4kRxfvBGmz9iBo', 'duration': '8s'},
#       {'placeId': 'ChIJURpknaTGt4kRIpZtGT5Ag0A', 'duration': '1s'},
#       {'placeId': 'ChIJLVKfhqTGt4kRK7M5POmgqb4', 'duration': '3s'},
#       {'placeId': 'ChIJH5PufaTGt4kRPOTwcBsXWTE', 'duration': '14s'},
#       {'placeId': 'ChIJq-zEiaPGt4kR1aMCq745mFY', 'duration': '14s'},
#       {'placeId': 'ChIJY3ie-aPGt4kR1gttmCrrLxY', 'duration': '22s'},
#       {'placeId': 'ChIJOyJ5VKHGt4kR3_7Eg-Rjl8w', 'duration': '4s'},
#       {'placeId': 'ChIJIQSDrKbGt4kRWthjc5wmFVk', 'duration': '6s'},
#       {'placeId': 'ChIJ-3eGr6bGt4kRk30VJIciy7w', 'duration': '10s'},
#       {'placeId': 'ChIJjWdgvabGt4kRpiuR77Y8q1A', 'duration': '6s'},
#       {'placeId': 'ChIJjWdgvabGt4kR9lmiojhfB1k', 'duration': '2s'},
#       {'placeId': 'ChIJvYORkKbGt4kRqMLT1tomgds', 'duration': '3s'},
#       {'placeId': 'ChIJ-dv3j6bGt4kRvKVjYVzAty4', 'duration': '3s'},
#       {'placeId': 'ChIJIb8phKbGt4kRS_32xUiK3m8', 'duration': '5s'},
#       {'placeId': 'ChIJN9UBfqbGt4kRETS6zgHJVy0', 'duration': '1s'},
#       {'placeId': 'ChIJN9UBfqbGt4kRCmNJKqF8_pg', 'duration': '0s'},
#       {'placeId': 'ChIJge9rfqbGt4kRXIGNQMzYhGs', 'duration': '3s'},
#       {'placeId': 'ChIJ2-vPeKbGt4kRY5PGlFlPeiY', 'duration': '2s'},
#       {'placeId': 'ChIJn2Ie2aXGt4kRDe8vjDDRIeg', 'duration': '12s'},
#       {'placeId': 'ChIJE-hq76XGt4kRKzJ3FIU9xcc', 'duration': '15s'},
#       {'placeId': 'ChIJC-Ft9KXGt4kR9g3s-kg_3U8', 'duration': '3s'},
#       {'placeId': 'ChIJS01p9aXGt4kRTxsffGpRtII', 'duration': '0s'},
#       {'placeId': 'ChIJS01p9aXGt4kRA-EXgu6r0lU', 'duration': '2s'},
#       {'placeId': 'ChIJOeVbZq_Gt4kRFhEOQVo2s2Q', 'duration': '18s'},
#       {'placeId': 'ChIJEYcSba_Gt4kRR_RwhM-0OCY', 'duration': '0s'},
#       {'placeId': 'ChIJ_zqpbK_Gt4kRp4LGQgg9QN0', 'duration': '6s'},
#       {'placeId': 'ChIJgYRBFa_Gt4kRiQk4v64uqIk', 'duration': '2s'},
#       {'placeId': 'ChIJlwO4M6_Gt4kRncU_0KonNxE', 'duration': '44s'},
#       {'placeId': 'ChIJ0aMG26jGt4kRrrSMp7FcSzI', 'duration': '0s'},
#       {'placeId': 'ChIJCR9a4ajGt4kRvf5MhD2PGIA', 'duration': '19s'},
#       {'placeId': 'ChIJpy1iq6nGt4kRHErILl7udCc', 'duration': '18s'},
#       {'placeId': 'ChIJV6SWs6nGt4kROUt4WVxCR08', 'duration': '1s'},
#       {'placeId': 'ChIJ0SNss6nGt4kRxyvf6zPWrdg', 'duration': '1s'},
#       {'placeId': 'ChIJHxSGTKjGt4kRa02xXvzVOhg', 'duration': '6s'},
#       {'placeId': 'ChIJSZnSTqjGt4kRO7cGyryUkxI', 'duration': '3s'},
#       {'placeId': 'ChIJJTxaNqjGt4kRVPDzyhy_hEI', 'duration': '11s'},
#       {'placeId': 'ChIJZ4QwMKjGt4kRBcMFBYFd-qY', 'duration': '8s'},
#       {'placeId': 'ChIJ7dSrIqjGt4kR_q3lWB_SHdM', 'duration': '12s'}],
#      'distanceMeters': 3450.1272972079905,
#      'travelMode': 'BICYCLE',
#      'confidence': 0.0},
#     'simplifiedRawPath': {'points': [{'latE7': 389874725,
#        'lngE7': -769447098,
#        'accuracyMeters': 37,
#        'timestamp': '2022-04-01T15:47:55.324Z'},
#       {'latE7': 389926376,
#        'lngE7': -769332962,
#        'accuracyMeters': 21,
#        'timestamp': '2022-04-01T15:51:57.837Z'}]}}},
#   {'placeVisit': {'location': {'latitudeE7': 389959742,
#      'longitudeE7': -769284073,
#      'placeId': 'ChIJQdjJF6jGt4kRQlYiYDyaIfc',
#      'address': '4815 Ruatan St\nBerwyn Heights, MD 20740\nUSA',
#      'name': '4815 Ruatan St',
#      'sourceInfo': {'deviceTag': -1787875010},
#      'locationConfidence': 90.589035,
#      'calibratedProbability': 63.814415},
#     'duration': {'startTimestamp': '2022-04-01T15:54:39.485Z',
#      'endTimestamp': '2022-04-01T16:41:48.852Z'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 389960104,
#     'centerLngE7': -769283958,
#     'visitConfidence': 76,
#     'otherCandidateLocations': [{'latitudeE7': 389970110,
#       'longitudeE7': -769295860,
#       'placeId': 'ChIJS3IcqwLEt4kRUkUcD9beZyk',
#       'address': '4717 Tecumseh St\nBerwyn Heights, MD 20740\nUSA',
#       'name': '4717 Tecumseh St',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 3.599672,
#       'calibratedProbability': 2.535748},
#      {'latitudeE7': 389961844,
#       'longitudeE7': -769288853,
#       'placeId': 'ChIJSb6cGqjGt4kRzVh1yP7m4Cg',
#       'address': 'Berwyn, 20740\nCollege Park, MD 20740\nUSA',
#       'name': 'USPS Collection Box',
#       'locationConfidence': 1.6887889,
#       'calibratedProbability': 1.1896482},
#      {'latitudeE7': 389977228,
#       'longitudeE7': -769311012,
#       'placeId': 'ChIJRyU6aB3Et4kRSgSc7ow7eGc',
#       'address': '8801 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Universal Barber Shop',
#       'locationConfidence': 1.2363951,
#       'calibratedProbability': 0.87096447},
#      {'latitudeE7': 389962961,
#       'longitudeE7': -769310713,
#       'placeId': 'ChIJiRm5EKPHt4kRIIfq2I-kSoE',
#       'address': '8601 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Lidl',
#       'locationConfidence': 0.7762314,
#       'calibratedProbability': 0.5468074}],
#     'editConfirmationStatus': 'NOT_CONFIRMED',
#     'locationConfidence': 76,
#     'placeVisitType': 'SINGLE_PLACE',
#     'placeVisitImportance': 'MAIN'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 389959961,
#      'longitudeE7': -769283521,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'endLocation': {'latitudeE7': 389961894,
#      'longitudeE7': -769285198,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'duration': {'startTimestamp': '2022-04-01T16:41:48.852Z',
#      'endTimestamp': '2022-04-01T17:01:58.680Z'},
#     'distance': 5889,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'MEDIUM',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 75.15862584114075},
#      {'activityType': 'CYCLING', 'probability': 12.488484382629395},
#      {'activityType': 'MOTORCYCLING', 'probability': 3.9710700511932373},
#      {'activityType': 'WALKING', 'probability': 3.903811052441597},
#      {'activityType': 'IN_BUS', 'probability': 1.6649836674332619},
#      {'activityType': 'STILL', 'probability': 1.0525715537369251},
#      {'activityType': 'IN_TRAIN', 'probability': 0.4598502069711685},
#      {'activityType': 'IN_FERRY', 'probability': 0.39404514245688915},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.39220661856234074},
#      {'activityType': 'RUNNING', 'probability': 0.2726387232542038},
#      {'activityType': 'SKIING', 'probability': 0.10161949321627617},
#      {'activityType': 'IN_TRAM', 'probability': 0.09355462971143425},
#      {'activityType': 'SAILING', 'probability': 0.0233659113291651},
#      {'activityType': 'FLYING', 'probability': 0.02317313483217731},
#      {'activityType': 'IN_VEHICLE', 'probability': 2.511463925713997e-06}],
#     'waypointPath': {'waypoints': [{'latE7': 389961090, 'lngE7': -769283142},
#       {'latE7': 389887275, 'lngE7': -769351348},
#       {'latE7': 389811058, 'lngE7': -769408111},
#       {'latE7': 389806327, 'lngE7': -769439544},
#       {'latE7': 389799003, 'lngE7': -769401397},
#       {'latE7': 389776725, 'lngE7': -769382019},
#       {'latE7': 389836044, 'lngE7': -769483184},
#       {'latE7': 389847526, 'lngE7': -769487457},
#       {'latE7': 389890594, 'lngE7': -769488754},
#       {'latE7': 390009994, 'lngE7': -769392166},
#       {'latE7': 389961509, 'lngE7': -769285354}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJ7dSrIqjGt4kR_q3lWB_SHdM',
#        'duration': '7s'},
#       {'placeId': 'ChIJ9cMLBajGt4kRlFOm-MEW6Tk', 'duration': '7s'},
#       {'placeId': 'ChIJ2RWPB6jGt4kRsZtdewnBSY0', 'duration': '7s'},
#       {'placeId': 'ChIJs5fp46fGt4kR4Ub5I215MEA', 'duration': '14s'},
#       {'placeId': 'ChIJbY9gwqfGt4kRlE_WO_tcBr0', 'duration': '4s'},
#       {'placeId': 'ChIJbY9gwqfGt4kReWTzg_fIjLw', 'duration': '10s'},
#       {'placeId': 'ChIJtT30vqfGt4kR4EzxPMxyEok', 'duration': '8s'},
#       {'placeId': 'ChIJoxD7vKfGt4kRsCeFFbRjXOM', 'duration': '3s'},
#       {'placeId': 'ChIJYR60pKfGt4kRMscL5m5kl7s', 'duration': '3s'},
#       {'placeId': 'ChIJYSiOr6fGt4kRvriW0HUqRao', 'duration': '2s'},
#       {'placeId': 'ChIJvf70rqfGt4kR1uYANS8RYVo', 'duration': '0s'},
#       {'placeId': 'ChIJRRc8rKfGt4kRpgC1yl5mNmE', 'duration': '1s'},
#       {'placeId': 'ChIJlaWPrKfGt4kRBu7vqm0N190', 'duration': '0s'},
#       {'placeId': 'ChIJg3ymrKfGt4kR7pchIooSP2A', 'duration': '0s'},
#       {'placeId': 'ChIJcYCiVKbGt4kRK4a90oiPDq8', 'duration': '0s'},
#       {'placeId': 'ChIJf90-VKbGt4kRHbCV2Iv6vTA', 'duration': '1s'},
#       {'placeId': 'ChIJqeaLVqbGt4kRh77UUSy6YP8', 'duration': '0s'},
#       {'placeId': 'ChIJATS7V6bGt4kRz1IqeckXWaw', 'duration': '1s'},
#       {'placeId': 'ChIJYx1uWKbGt4kRrfX9qySzPII', 'duration': '2s'},
#       {'placeId': 'ChIJF8YF9qbGt4kRq-xOw6ChBes', 'duration': '1s'},
#       {'placeId': 'ChIJU4699abGt4kRV37TFocxO94', 'duration': '0s'},
#       {'placeId': 'ChIJwykP9abGt4kR2eDPQTwsrN0', 'duration': '0s'},
#       {'placeId': 'ChIJUZgQi6bGt4kRFhuy0jpRl7k', 'duration': '7s'},
#       {'placeId': 'ChIJNe4lj6bGt4kRSMD5JZmGgP8', 'duration': '6s'},
#       {'placeId': 'ChIJBa6VhabGt4kRefoAESd3IRg', 'duration': '2s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRSua6zVKChfQ', 'duration': '1s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRKSCI3Arn_O4', 'duration': '4s'},
#       {'placeId': 'ChIJUVexgqbGt4kREYow6lIg9I8', 'duration': '0s'},
#       {'placeId': 'ChIJ1eP_J6TGt4kRC85_1nga4gY', 'duration': '0s'},
#       {'placeId': 'ChIJgTLMJ6TGt4kR9vdEU_Jy5P4', 'duration': '1s'},
#       {'placeId': 'ChIJ54VqJqTGt4kR6svpTnpad6Y', 'duration': '1s'},
#       {'placeId': 'ChIJKR_YJaTGt4kR7DjkDdbWGgQ', 'duration': '0s'},
#       {'placeId': 'ChIJKR_YJaTGt4kRZZ_4-RmSFbA', 'duration': '0s'},
#       {'placeId': 'ChIJ15nDJKTGt4kRwI5PgVPH0bs', 'duration': '6s'},
#       {'placeId': 'ChIJBXXnPqTGt4kRKkwbu7JTb8c', 'duration': '3s'},
#       {'placeId': 'ChIJBXXnPqTGt4kR4SXMectGJxE', 'duration': '7s'},
#       {'placeId': 'ChIJB_tMQKTGt4kRilHprYUbYEc', 'duration': '0s'},
#       {'placeId': 'ChIJbzPxQaTGt4kRkkZm1R3WXJA', 'duration': '3s'},
#       {'placeId': 'ChIJ-T4vaKTGt4kR-mwy6pdXey8', 'duration': '1s'},
#       {'placeId': 'ChIJ-T4vaKTGt4kR4MsLOyf6uYk', 'duration': '0s'},
#       {'placeId': 'ChIJy5KoZ6TGt4kRoAVXwcUe_BU', 'duration': '9s'},
#       {'placeId': 'ChIJZRYXYqTGt4kRLjQElhmml8g', 'duration': '2s'},
#       {'placeId': 'ChIJdfwAiaTGt4kRUKxYJc2IEpY', 'duration': '5s'},
#       {'placeId': 'ChIJ2UJMj6TGt4kRZ5mcKlRG4_Q', 'duration': '3s'},
#       {'placeId': 'ChIJdX9LhaTGt4kRjjRZ0N9gDkk', 'duration': '1s'},
#       {'placeId': 'ChIJdX9LhaTGt4kRZ1E3Q9Z-MpQ', 'duration': '1s'},
#       {'placeId': 'ChIJn-_-mqTGt4kRe-rwy0U-cHA', 'duration': '6s'},
#       {'placeId': 'ChIJ_0jdmKTGt4kRnUUAHYE6RP0', 'duration': '1s'},
#       {'placeId': 'ChIJVca_mKTGt4kRYNlBbUbeBg4', 'duration': '2s'},
#       {'placeId': 'ChIJ7bAToaTGt4kRogqBrK_g7G4', 'duration': '12s'},
#       {'placeId': 'ChIJabjVrLzGt4kR10XIUuOrboQ', 'duration': '9s'},
#       {'placeId': 'ChIJabjVrLzGt4kRjrSgQ5Hpmd4', 'duration': '11s'},
#       {'placeId': 'ChIJ79_Ou7zGt4kReBCB769B3vY', 'duration': '1s'},
#       {'placeId': 'ChIJ79_Ou7zGt4kR48kfOKgdzcw', 'duration': '6s'},
#       {'placeId': 'ChIJ2Vt-lbzGt4kRvzJerPKM1A0', 'duration': '8s'},
#       {'placeId': 'ChIJ3TK37LzGt4kRTbDVYZvMUzY', 'duration': '7s'},
#       {'placeId': 'ChIJnUVj8rzGt4kRDhCyxCCpBhw', 'duration': '2s'},
#       {'placeId': 'ChIJgdsT9rzGt4kRWIFTiHI9dgs', 'duration': '9s'},
#       {'placeId': 'ChIJgdsT9rzGt4kRQbJQtQcqEVc', 'duration': '9s'},
#       {'placeId': 'ChIJVZa6SLzGt4kRtCBE3Mjmwks', 'duration': '14s'},
#       {'placeId': 'ChIJTZC1MbzGt4kRxk_cDQymYqI', 'duration': '11s'},
#       {'placeId': 'ChIJSfOVKbzGt4kRMbLhZvr32dQ', 'duration': '11s'},
#       {'placeId': 'ChIJlUbAg77Gt4kRRVI-y8Hhvbw', 'duration': '1s'},
#       {'placeId': 'ChIJoccGhL7Gt4kRDXrVklkD7Hs', 'duration': '1s'},
#       {'placeId': 'ChIJleXQhb7Gt4kRRUGBKKhw9cM', 'duration': '6s'},
#       {'placeId': 'ChIJq8omj77Gt4kRFtDvKZzVa14', 'duration': '8s'},
#       {'placeId': 'ChIJleKNjL7Gt4kRXuTHZxykdoQ', 'duration': '7s'},
#       {'placeId': 'ChIJWYeZ877Gt4kRxP-Zh1mINlI', 'duration': '10s'},
#       {'placeId': 'ChIJM2F19r7Gt4kRQ_ZoBGVdBc0', 'duration': '11s'},
#       {'placeId': 'ChIJM2F19r7Gt4kRzzv0xho3lDM', 'duration': '5s'},
#       {'placeId': 'ChIJB3yzXr7Gt4kR9i8rgLeQoks', 'duration': '4s'},
#       {'placeId': 'ChIJdRlzXL7Gt4kR3UxDuj8lBNw', 'duration': '3s'},
#       {'placeId': 'ChIJZWqfXL7Gt4kRlC_cwffUmtM', 'duration': '3s'},
#       {'placeId': 'ChIJQ8COQ77Gt4kRAlkhzSGa7C0', 'duration': '6s'},
#       {'placeId': 'ChIJQ8COQ77Gt4kRC6ZO846_oOk', 'duration': '2s'},
#       {'placeId': 'ChIJKVKoQL7Gt4kR_qr16Glr3Ic', 'duration': '8s'},
#       {'placeId': 'ChIJD6auPr7Gt4kRsgWdgjI2TPM', 'duration': '3s'},
#       {'placeId': 'ChIJZzp9O77Gt4kR4uqG_4esrxY', 'duration': '3s'},
#       {'placeId': 'ChIJNSKQJL7Gt4kRyKJwNvt0qUA', 'duration': '3s'},
#       {'placeId': 'ChIJv5GUJr7Gt4kRVPIqiBwm4GM', 'duration': '4s'},
#       {'placeId': 'ChIJ2b3jiJXGt4kRxEAJG48NPL0', 'duration': '9s'},
#       {'placeId': 'ChIJg97Wj5XGt4kRk9eBqWp77bY', 'duration': '3s'},
#       {'placeId': 'ChIJgZKUvJXGt4kRl3u4WIPVfq8', 'duration': '4s'},
#       {'placeId': 'ChIJgZKUvJXGt4kRInU3HcSJOdM', 'duration': '24s'},
#       {'placeId': 'ChIJk4KprZXGt4kR8r8VgUO8EeA', 'duration': '3s'},
#       {'placeId': 'ChIJ497DrJXGt4kRqMXf5HAZTf4', 'duration': '0s'},
#       {'placeId': 'ChIJKzZWq5XGt4kRCmCXbBKbjJU', 'duration': '1s'},
#       {'placeId': 'ChIJ159Wq5XGt4kRYRaemwe45A4', 'duration': '0s'},
#       {'placeId': 'ChIJ4-thqpXGt4kRlAr_nkbiDoM', 'duration': '9s'},
#       {'placeId': 'ChIJe4ceBpXGt4kRoAOI9Rhhtmc', 'duration': '8s'},
#       {'placeId': 'ChIJ-SSxDZXGt4kRip5gwGsgizw', 'duration': '6s'},
#       {'placeId': 'ChIJM1x7cpXGt4kRRN-aWAgAa9A', 'duration': '7s'},
#       {'placeId': 'ChIJP5wdcZXGt4kRYSMeyghIc1g', 'duration': '11s'},
#       {'placeId': 'ChIJV2qReZXGt4kRh2OsT1A1FQ0', 'duration': '2s'},
#       {'placeId': 'ChIJe8FAfpXGt4kRx0z4eiQN5FM', 'duration': '12s'},
#       {'placeId': 'ChIJudF11L_Gt4kRrZg5_Vi2TSc', 'duration': '0s'},
#       {'placeId': 'ChIJqVc_zL_Gt4kRO43ceSD3y6c', 'duration': '17s'},
#       {'placeId': 'ChIJuXQ0tL_Gt4kRZf6Nen0omWg', 'duration': '2s'},
#       {'placeId': 'ChIJZ206sr_Gt4kReVafmXsykY4', 'duration': '11s'},
#       {'placeId': 'ChIJbUEXqr_Gt4kRjRZ-5Zi1Bcc', 'duration': '3s'},
#       {'placeId': 'ChIJ76alAL_Gt4kR7AnKKvkGSpU', 'duration': '0s'},
#       {'placeId': 'ChIJ76alAL_Gt4kRFlwS7MKWGiI', 'duration': '17s'},
#       {'placeId': 'ChIJ5ygxBL_Gt4kRhqV9jNLbeSA', 'duration': '6s'},
#       {'placeId': 'ChIJCcvaDr_Gt4kRKOsKENbsYAM', 'duration': '6s'},
#       {'placeId': 'ChIJyf6vDL_Gt4kRLlh2KnEJECQ', 'duration': '6s'},
#       {'placeId': 'ChIJgfowcb_Gt4kRykm9CqkFgg4', 'duration': '6s'},
#       {'placeId': 'ChIJTUPRe7_Gt4kRhnJ37aQJEB4', 'duration': '5s'},
#       {'placeId': 'ChIJazuOfr_Gt4kR2-NUsA44C7I', 'duration': '5s'},
#       {'placeId': 'ChIJkbhXhL_Gt4kRV4PUgwdBDMo', 'duration': '12s'},
#       {'placeId': 'ChIJkbpPkb_Gt4kRmBCxk6EmuOM', 'duration': '8s'},
#       {'placeId': 'ChIJG45hlb_Gt4kRchlA-ngSnVQ', 'duration': '3s'},
#       {'placeId': 'ChIJIblewL_Gt4kRQmYB9aBo_hw', 'duration': '2s'},
#       {'placeId': 'ChIJ98ms3L_Gt4kRuBM1puPiRsc', 'duration': '10s'},
#       {'placeId': 'ChIJ16yyb5XGt4kRluEiPH2mXj4', 'duration': '18s'},
#       {'placeId': 'ChIJn0r8cpXGt4kRwVKoYbzqGcU', 'duration': '6s'},
#       {'placeId': 'ChIJi5IQCJXGt4kRh37YNak6_FA', 'duration': '30s'},
#       {'placeId': 'ChIJKzZWq5XGt4kRcoG-tGDFnvo', 'duration': '1s'},
#       {'placeId': 'ChIJpzgCU5TGt4kR1q2ql1I0tXs', 'duration': '7s'},
#       {'placeId': 'ChIJ3x7MUZTGt4kRZsIeuQ5DzTg', 'duration': '5s'},
#       {'placeId': 'ChIJrV2qWpTGt4kRLE46mC2iG4M', 'duration': '0s'},
#       {'placeId': 'ChIJc4a1XJTGt4kRWs4B-SGHNYk', 'duration': '9s'},
#       {'placeId': 'ChIJN5X0ZZTGt4kRbDAlApKZ4Yg', 'duration': '6s'},
#       {'placeId': 'ChIJa0efepTGt4kRLubwOvjHsjw', 'duration': '0s'},
#       {'placeId': 'ChIJjV-HcJTGt4kRsMwJ7PbZAT4', 'duration': '0s'},
#       {'placeId': 'ChIJJb5HcZTGt4kRyOkhQfZJ0wE', 'duration': '4s'},
#       {'placeId': 'ChIJcwDtdJTGt4kR-C2uzqOAXJs', 'duration': '2s'},
#       {'placeId': 'ChIJsVC0CpTGt4kRTysA3x4P9g0', 'duration': '2s'},
#       {'placeId': 'ChIJtRs49ZPGt4kRi57x_iJqv38', 'duration': '0s'},
#       {'placeId': 'ChIJiYCl85PGt4kRnNlBLSiUhf0', 'duration': '10s'},
#       {'placeId': 'ChIJhfK685PGt4kRoAW3xy-zaVU', 'duration': '4s'},
#       {'placeId': 'ChIJCdfq5ZPGt4kRho99U-IJ41w', 'duration': '1s'},
#       {'placeId': 'ChIJJWac5pPGt4kRrOaejd9n-oM', 'duration': '1s'},
#       {'placeId': 'ChIJhccW4ZPGt4kRfJAolssWvFQ', 'duration': '2s'},
#       {'placeId': 'ChIJR7k04JPGt4kRRE-O3lKHV9k', 'duration': '0s'},
#       {'placeId': 'ChIJfeLKX5HGt4kRLtCUF96ImUk', 'duration': '4s'},
#       {'placeId': 'ChIJA7t7aJHGt4kR9vxv-NwnJQ4', 'duration': '11s'},
#       {'placeId': 'ChIJ6S-Ua5HGt4kRfZaWYQ8PH-8', 'duration': '0s'},
#       {'placeId': 'ChIJKyYDa5HGt4kRtwb3CfVQu2c', 'duration': '1s'},
#       {'placeId': 'ChIJmdwXQJHGt4kRjY29x_6I2jQ', 'duration': '2s'},
#       {'placeId': 'ChIJ83eAOJHGt4kR6Uj9e3PalrA', 'duration': '8s'},
#       {'placeId': 'ChIJg3_FNZHGt4kRxI4BgIFL87U', 'duration': '5s'},
#       {'placeId': 'ChIJFwEuy5bGt4kRuZkS_hhyzyM', 'duration': '1s'},
#       {'placeId': 'ChIJs5xyzJbGt4kRvirdcWBIQaw', 'duration': '5s'},
#       {'placeId': 'ChIJ3-fczZbGt4kRMpHgU5VPPI0', 'duration': '3s'},
#       {'placeId': 'ChIJySB90pbGt4kRbHQdbQgVhMI', 'duration': '1s'},
#       {'placeId': 'ChIJJ6ni0pbGt4kRdKdE2-9kYrE', 'duration': '2s'},
#       {'placeId': 'ChIJ3yla05bGt4kRShzmR2VhN8M', 'duration': '2s'},
#       {'placeId': 'ChIJRZdY1ZbGt4kRXgxM4x8MHjg', 'duration': '8s'},
#       {'placeId': 'ChIJHZOXLJfGt4kRSmgSUePoHCA', 'duration': '0s'},
#       {'placeId': 'ChIJYW4MMpfGt4kRvTW9RSWoYh4', 'duration': '4s'},
#       {'placeId': 'ChIJdWISMpfGt4kRj5qasj_LLG8', 'duration': '3s'},
#       {'placeId': 'ChIJ1VI-MZfGt4kR9w3pXgHMM38', 'duration': '1s'},
#       {'placeId': 'ChIJ5dnBNpfGt4kRxTAtFfIj3BQ', 'duration': '4s'},
#       {'placeId': 'ChIJpQxDNpfGt4kRtfa_bYfPyYs', 'duration': '0s'},
#       {'placeId': 'ChIJhejxN5fGt4kR1CVuWeZco4Y', 'duration': '7s'},
#       {'placeId': 'ChIJByubOJfGt4kRjMFpcWQs0lk', 'duration': '1s'},
#       {'placeId': 'ChIJ6zZJQJfGt4kR022zKT33JhU', 'duration': '11s'},
#       {'placeId': 'ChIJq52AaZfGt4kRpjSUhCtOqAQ', 'duration': '3s'},
#       {'placeId': 'ChIJ7V2vaZfGt4kR9CpGoy1uIyQ', 'duration': '3s'},
#       {'placeId': 'ChIJizZcaJfGt4kRQy_6lyFrkVI', 'duration': '1s'},
#       {'placeId': 'ChIJ5xq0Z5fGt4kRAAYL1zKCSDE', 'duration': '8s'},
#       {'placeId': 'ChIJRcjPYZfGt4kR3q-MyPsLpbA', 'duration': '18s'},
#       {'placeId': 'ChIJPxUf3JnGt4kRCk705U6tXzc', 'duration': '0s'},
#       {'placeId': 'ChIJ2_HB5pnGt4kRjOaRq936LBY', 'duration': '17s'},
#       {'placeId': 'ChIJs82a-JnGt4kRNsSDa48x4ws', 'duration': '11s'},
#       {'placeId': 'ChIJU4uMA5rGt4kRrgAZ5YF3z18', 'duration': '2s'},
#       {'placeId': 'ChIJJRLLBZrGt4kRsIVzFYnhUwI', 'duration': '1s'},
#       {'placeId': 'ChIJl2FjC5rGt4kRgO33b7jYwPQ', 'duration': '8s'},
#       {'placeId': 'ChIJV-lSC5rGt4kRSMCNFFh3umQ', 'duration': '0s'},
#       {'placeId': 'ChIJDzSOdJrGt4kRcj6mfi7SMGU', 'duration': '0s'},
#       {'placeId': 'ChIJ6yhpdJrGt4kRVHt08YplusU', 'duration': '0s'},
#       {'placeId': 'ChIJPQwfdJrGt4kRns_3CRFGY18', 'duration': '0s'},
#       {'placeId': 'ChIJyYXpdprGt4kRqMpi2IvTbGY', 'duration': '0s'},
#       {'placeId': 'ChIJd8Zsd5rGt4kRHPUSVscroEA', 'duration': '2s'},
#       {'placeId': 'ChIJH9dieZrGt4kRtxNv4zwYk_E', 'duration': '6s'},
#       {'placeId': 'ChIJExIIe5rGt4kRhc_RUF4c_Qk', 'duration': '0s'},
#       {'placeId': 'ChIJH17wZJrGt4kRe354bk8wECk', 'duration': '8s'},
#       {'placeId': 'ChIJFcWSZprGt4kRCRpwQ0A48ho', 'duration': '0s'},
#       {'placeId': 'ChIJuQB4XJrGt4kR4oeeeC0-GrU', 'duration': '17s'},
#       {'placeId': 'ChIJ4YpzUZrGt4kRe9K4X_59APo', 'duration': '0s'},
#       {'placeId': 'ChIJOYNOUprGt4kRiZ1KpFw_JlQ', 'duration': '3s'},
#       {'placeId': 'ChIJf-RBrZvGt4kR4BtxJlDLq1Q', 'duration': '4s'},
#       {'placeId': 'ChIJJxkxrJvGt4kRZuoueZlWNUk', 'duration': '1s'},
#       {'placeId': 'ChIJJ8btq5vGt4kRPKFl54bnHj4', 'duration': '1s'},
#       {'placeId': 'ChIJzW01qpvGt4kRhIQ8pQTb2WM', 'duration': '0s'},
#       {'placeId': 'ChIJJ-qrAJvGt4kR7hhI3APNQPg', 'duration': '4s'},
#       {'placeId': 'ChIJEUvbBpvGt4kRe-eK-scgvqc', 'duration': '1s'},
#       {'placeId': 'ChIJWTOrBZvGt4kRN3PANLkeVO8', 'duration': '6s'},
#       {'placeId': 'ChIJpWsDFpvGt4kR-G2jpZWsfUE', 'duration': '6s'},
#       {'placeId': 'ChIJv0oxPJvGt4kRk3po5JOPihI', 'duration': '3s'},
#       {'placeId': 'ChIJ-QEfbJvGt4kRHcQJtdx_Odk', 'duration': '4s'},
#       {'placeId': 'ChIJ-10jh5zGt4kRdVro6sba2qY', 'duration': '3s'},
#       {'placeId': 'ChIJ-10jh5zGt4kRwbRLfDXT_nw', 'duration': '10s'},
#       {'placeId': 'ChIJ4Ud_T5zGt4kR_U3EGepTlbo', 'duration': '3s'},
#       {'placeId': 'ChIJSQItyp3Gt4kRvttA4rY5odY', 'duration': '6s'},
#       {'placeId': 'ChIJjVNfD57Gt4kRmP0oqqqhHNU', 'duration': '13s'},
#       {'placeId': 'ChIJZ9wRkCDEt4kROHjTZ3ljhDI', 'duration': '5s'},
#       {'placeId': 'ChIJfSpFiiDEt4kRrqoXHfk1W6M', 'duration': '3s'},
#       {'placeId': 'ChIJgcMLXiDEt4kR5uNBHTsIaIs', 'duration': '5s'},
#       {'placeId': 'ChIJ4ThjRCDEt4kRKEagzgC8iDk', 'duration': '8s'},
#       {'placeId': 'ChIJK6ycNyDEt4kRjWGTXmpwoV4', 'duration': '6s'},
#       {'placeId': 'ChIJZYgkLCDEt4kRAwGyT9G7dxo', 'duration': '9s'},
#       {'placeId': 'ChIJY3c3Dx_Et4kRWKLqntiUK_A', 'duration': '17s'},
#       {'placeId': 'ChIJQ6-fkx7Et4kRegvwI2BjeOQ', 'duration': '3s'},
#       {'placeId': 'ChIJyUJ2mR7Et4kRyFObazu7qvc', 'duration': '1s'},
#       {'placeId': 'ChIJ3TLtFRzEt4kRf-V-bPXPC6s', 'duration': '11s'},
#       {'placeId': 'ChIJOxMblhzEt4kRQigo3Nrnftg', 'duration': '15s'},
#       {'placeId': 'ChIJcU0nSgPEt4kRL8q5uZN2q1E', 'duration': '5s'},
#       {'placeId': 'ChIJAw4yLgPEt4kR8UoGH4U9Ef8', 'duration': '6s'},
#       {'placeId': 'ChIJ1xM81gLEt4kRh8ZWMCzn3uk', 'duration': '2s'},
#       {'placeId': 'ChIJW8unzQLEt4kR89tBsyMrIag', 'duration': '2s'},
#       {'placeId': 'ChIJVd9_ywLEt4kRaLLwr1U2Rxo', 'duration': '12s'},
#       {'placeId': 'ChIJVd9_ywLEt4kR6Bl9v5LK_bo', 'duration': '0s'},
#       {'placeId': 'ChIJs9EIyQLEt4kRmkUB-xw69CU', 'duration': '0s'},
#       {'placeId': 'ChIJVd9_ywLEt4kRdypyZ885gr0', 'duration': '0s'},
#       {'placeId': 'ChIJL4fWyQLEt4kRZmEqk0UocPs', 'duration': '0s'},
#       {'placeId': 'ChIJOcx0sQLEt4kRjeQCO5jQavc', 'duration': '5s'},
#       {'placeId': 'ChIJOcx0sQLEt4kRjq7ebYQxv5M', 'duration': '8s'},
#       {'placeId': 'ChIJA9jzAajGt4kRGRzC-VJo3l0', 'duration': '16s'},
#       {'placeId': 'ChIJ9cMLBajGt4kRlVOm-MEW6Tk', 'duration': '6s'},
#       {'placeId': 'ChIJ7dSrIqjGt4kR_63lWB_SHdM', 'duration': '4s'}],
#      'distanceMeters': 9347.53655108672,
#      'travelMode': 'DRIVE',
#      'confidence': 0.9532693476339916},
#     'simplifiedRawPath': {'points': [{'latE7': 389811363,
#        'lngE7': -769406281,
#        'accuracyMeters': 21,
#        'timestamp': '2022-04-01T16:49:42.415Z'},
#       {'latE7': 389800797,
#        'lngE7': -769400940,
#        'accuracyMeters': 16,
#        'timestamp': '2022-04-01T16:51:04.094Z'},
#       {'latE7': 389835472,
#        'lngE7': -769482956,
#        'accuracyMeters': 42,
#        'timestamp': '2022-04-01T16:53:53.940Z'},
#       {'latE7': 389893265,
#        'lngE7': -769487762,
#        'accuracyMeters': 88,
#        'timestamp': '2022-04-01T16:55:14.773Z'}]},
#     'parkingEvent': {'location': {'latitudeE7': 389959970,
#       'longitudeE7': -769283628,
#       'accuracyMetres': 74},
#      'method': 'END_OF_ACTIVITY_SEGMENT',
#      'locationSource': 'FROM_RAW_LOCATION',
#      'timestamp': '2022-04-01T17:03:12.728Z'}}},
#   {'placeVisit': {'location': {'latitudeE7': 389959742,
#      'longitudeE7': -769284073,
#      'placeId': 'ChIJQdjJF6jGt4kRQlYiYDyaIfc',
#      'address': '4815 Ruatan St\nBerwyn Heights, MD 20740\nUSA',
#      'name': '4815 Ruatan St',
#      'sourceInfo': {'deviceTag': -1787875010},
#      'locationConfidence': 90.74489,
#      'calibratedProbability': 67.177246},
#     'duration': {'startTimestamp': '2022-04-01T17:01:58.680Z',
#      'endTimestamp': '2022-04-01T17:56:50.999Z'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 389960200,
#     'centerLngE7': -769284008,
#     'visitConfidence': 82,
#     'otherCandidateLocations': [{'latitudeE7': 389970110,
#       'longitudeE7': -769295860,
#       'placeId': 'ChIJS3IcqwLEt4kRUkUcD9beZyk',
#       'address': '4717 Tecumseh St\nBerwyn Heights, MD 20740\nUSA',
#       'name': '4717 Tecumseh St',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 4.10494,
#       'calibratedProbability': 3.038833},
#      {'latitudeE7': 389961844,
#       'longitudeE7': -769288853,
#       'placeId': 'ChIJSb6cGqjGt4kRzVh1yP7m4Cg',
#       'address': 'Berwyn, 20740\nCollege Park, MD 20740\nUSA',
#       'name': 'USPS Collection Box',
#       'locationConfidence': 2.551046,
#       'calibratedProbability': 1.8885057},
#      {'latitudeE7': 389977228,
#       'longitudeE7': -769311012,
#       'placeId': 'ChIJRyU6aB3Et4kRSgSc7ow7eGc',
#       'address': '8801 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Universal Barber Shop',
#       'locationConfidence': 0.7714605,
#       'calibratedProbability': 0.571102},
#      {'latitudeE7': 389962961,
#       'longitudeE7': -769310713,
#       'placeId': 'ChIJiRm5EKPHt4kRIIfq2I-kSoE',
#       'address': '8601 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Lidl',
#       'locationConfidence': 0.6099889,
#       'calibratedProbability': 0.45156676}],
#     'editConfirmationStatus': 'NOT_CONFIRMED',
#     'locationConfidence': 76,
#     'placeVisitType': 'SINGLE_PLACE',
#     'placeVisitImportance': 'MAIN'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 389962056,
#      'longitudeE7': -769287358,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'endLocation': {'latitudeE7': 389881245,
#      'longitudeE7': -769398750,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'duration': {'startTimestamp': '2022-04-01T17:56:50.999Z',
#      'endTimestamp': '2022-04-01T18:01:47.945Z'},
#     'distance': 1429,
#     'activityType': 'CYCLING',
#     'confidence': 'MEDIUM',
#     'activities': [{'activityType': 'CYCLING',
#       'probability': 66.03841781616211},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 17.825710773468018},
#      {'activityType': 'WALKING', 'probability': 12.892501056194305},
#      {'activityType': 'MOTORCYCLING', 'probability': 1.3367277570068836},
#      {'activityType': 'RUNNING', 'probability': 0.8708806708455086},
#      {'activityType': 'STILL', 'probability': 0.4474373534321785},
#      {'activityType': 'IN_BUS', 'probability': 0.26083614211529493},
#      {'activityType': 'SKIING', 'probability': 0.13914641458541155},
#      {'activityType': 'IN_FERRY', 'probability': 0.09928337531164289},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.031081191264092922},
#      {'activityType': 'IN_TRAIN', 'probability': 0.023864432296250015},
#      {'activityType': 'SAILING', 'probability': 0.017699282034300268},
#      {'activityType': 'IN_TRAM', 'probability': 0.01598684029886499},
#      {'activityType': 'FLYING', 'probability': 0.000423274832428433},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.076849387438017e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 389961891, 'lngE7': -769287414},
#       {'latE7': 389899368, 'lngE7': -769352188},
#       {'latE7': 389880981, 'lngE7': -769398727}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJ7dSrIqjGt4kR_q3lWB_SHdM',
#        'duration': '3s'},
#       {'placeId': 'ChIJ9cMLBajGt4kRlFOm-MEW6Tk', 'duration': '13s'},
#       {'placeId': 'ChIJ2RWPB6jGt4kRsZtdewnBSY0', 'duration': '11s'},
#       {'placeId': 'ChIJs5fp46fGt4kR4Ub5I215MEA', 'duration': '15s'},
#       {'placeId': 'ChIJbY9gwqfGt4kRlE_WO_tcBr0', 'duration': '4s'},
#       {'placeId': 'ChIJbY9gwqfGt4kReWTzg_fIjLw', 'duration': '7s'},
#       {'placeId': 'ChIJtT30vqfGt4kR4EzxPMxyEok', 'duration': '4s'},
#       {'placeId': 'ChIJoxD7vKfGt4kRsCeFFbRjXOM', 'duration': '2s'},
#       {'placeId': 'ChIJYR60pKfGt4kRMscL5m5kl7s', 'duration': '3s'},
#       {'placeId': 'ChIJYSiOr6fGt4kRvriW0HUqRao', 'duration': '2s'},
#       {'placeId': 'ChIJvf70rqfGt4kR1uYANS8RYVo', 'duration': '1s'},
#       {'placeId': 'ChIJRRc8rKfGt4kRpgC1yl5mNmE', 'duration': '1s'},
#       {'placeId': 'ChIJlaWPrKfGt4kRBu7vqm0N190', 'duration': '1s'},
#       {'placeId': 'ChIJg3ymrKfGt4kR7pchIooSP2A', 'duration': '1s'},
#       {'placeId': 'ChIJcYCiVKbGt4kRK4a90oiPDq8', 'duration': '1s'},
#       {'placeId': 'ChIJf90-VKbGt4kRHbCV2Iv6vTA', 'duration': '1s'},
#       {'placeId': 'ChIJqeaLVqbGt4kRh77UUSy6YP8', 'duration': '0s'},
#       {'placeId': 'ChIJATS7V6bGt4kRz1IqeckXWaw', 'duration': '2s'},
#       {'placeId': 'ChIJYx1uWKbGt4kRrfX9qySzPII', 'duration': '2s'},
#       {'placeId': 'ChIJF8YF9qbGt4kRq-xOw6ChBes', 'duration': '2s'},
#       {'placeId': 'ChIJU4699abGt4kRV37TFocxO94', 'duration': '1s'},
#       {'placeId': 'ChIJwykP9abGt4kR2eDPQTwsrN0', 'duration': '0s'},
#       {'placeId': 'ChIJUZgQi6bGt4kRFhuy0jpRl7k', 'duration': '7s'},
#       {'placeId': 'ChIJNe4lj6bGt4kRSMD5JZmGgP8', 'duration': '6s'},
#       {'placeId': 'ChIJBa6VhabGt4kRefoAESd3IRg', 'duration': '3s'},
# ...
#     'distance': 756,
#     'activityType': 'WALKING',
#     'confidence': 'LOW',
#     'activities': [{'activityType': 'WALKING',
#       'probability': 42.89357364177704},
#      {'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 33.00986886024475},
#      {'activityType': 'CYCLING', 'probability': 14.982111752033234},
#      {'activityType': 'IN_BUS', 'probability': 3.2444212585687637},
#      {'activityType': 'STILL', 'probability': 2.537236362695694},
#      {'activityType': 'MOTORCYCLING', 'probability': 1.4858544804155827},
#      {'activityType': 'RUNNING', 'probability': 1.0042667388916016},
#      {'activityType': 'IN_TRAM', 'probability': 0.3029134124517441},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.26066910941153765},
#      {'activityType': 'IN_TRAIN', 'probability': 0.11613713577389717},
#      {'activityType': 'IN_FERRY', 'probability': 0.1047380268573761},
#      {'activityType': 'SKIING', 'probability': 0.043104670476168394},
#      {'activityType': 'SAILING', 'probability': 0.00834591337479651},
#      {'activityType': 'FLYING', 'probability': 0.006749429303454235},
#      {'activityType': 'IN_VEHICLE', 'probability': 3.623797084628677e-06}],
#     'waypointPath': {'waypoints': [{'latE7': 389868507, 'lngE7': -769415359},
#       {'latE7': 389834556, 'lngE7': -769414520},
#       {'latE7': 389804534, 'lngE7': -769399261}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJKwCZ4ZfGt4kR7c1P4N4GqaY',
#        'duration': '9s'},
#       {'placeId': 'ChIJl3jR35fGt4kRduJXCjGY5Yo', 'duration': '8s'},
#       {'placeId': 'ChIJSUyN35fGt4kRMNic-Ii99ys', 'duration': '5s'},
#       {'placeId': 'ChIJc0Oi2JfGt4kRcNdFm2UwzoE', 'duration': '23s'},
#       {'placeId': 'ChIJM77815fGt4kRhLEbXfCoB18', 'duration': '3s'},
#       {'placeId': 'ChIJjwoB1pfGt4kRqpYkZ7MNElk', 'duration': '28s'},
#       {'placeId': 'ChIJyeD_f73Gt4kRPK6gp5y8a14', 'duration': '6s'},
#       {'placeId': 'ChIJnz2eKpbGt4kRIJ8J3V1wDN4', 'duration': '4s'},
#       {'placeId': 'ChIJl1Z_KpbGt4kRuuYx2nZolz8', 'duration': '4s'},
#       {'placeId': 'ChIJhYepgL3Gt4kRnBIY-3BMlSA', 'duration': '9s'},
#       {'placeId': 'ChIJ-3LeKZbGt4kRKgeVCPcF_m8', 'duration': '4s'},
#       {'placeId': 'ChIJ_0kOKJbGt4kRsvn1jn3nsPg', 'duration': '24s'},
#       {'placeId': 'ChIJF5JlJ5bGt4kRTKEatUh0zBw', 'duration': '8s'},
#       {'placeId': 'ChIJE69ZJ5bGt4kRchWPlZMvijI', 'duration': '1s'},
#       {'placeId': 'ChIJeyMHir3Gt4kR2-dPVXSsfWw', 'duration': '7s'},
#       {'placeId': 'ChIJUWFvIJbGt4kR2W2waaE8Ci4', 'duration': '13s'},
#       {'placeId': 'ChIJt_TXIZbGt4kRqVexuzGkjcQ', 'duration': '6s'},
#       {'placeId': 'ChIJcaMfH5bGt4kRpWVOexj0uj4', 'duration': '13s'},
#       {'placeId': 'ChIJLURWHJbGt4kRAQZa-w2S6qI', 'duration': '17s'},
#       {'placeId': 'ChIJy5EoA5bGt4kRYIYGBJLP6tk', 'duration': '3s'},
#       {'placeId': 'ChIJN0ywA5bGt4kR0L4oLzYE0zA', 'duration': '14s'},
#       {'placeId': 'ChIJ96fwAJbGt4kRhLImCR1JqCQ', 'duration': '17s'},
#       {'placeId': 'ChIJCXpM_pXGt4kR9d06HmJ7EpQ', 'duration': '7s'},
#       {'placeId': 'ChIJ1arf_pXGt4kRYz1FZfaAmMw', 'duration': '19s'},
#       {'placeId': 'ChIJPSwA-ZXGt4kRwmMsb3s_Y9Q', 'duration': '11s'},
#       {'placeId': 'ChIJE48l-JXGt4kRlItua9BiUfg', 'duration': '4s'},
#       {'placeId': 'ChIJgwQc-JXGt4kRXWQX9eCd4X8', 'duration': '2s'},
#       {'placeId': 'ChIJN_sgHb7Gt4kRUIpGfBHdMuo', 'duration': '21s'},
#       {'placeId': 'ChIJbSHlG77Gt4kRUQ6hdyYTWMc', 'duration': '11s'},
#       {'placeId': 'ChIJ1dTcGL7Gt4kRVIHyZ4R_VgI', 'duration': '10s'},
#       {'placeId': 'ChIJ414SIr7Gt4kRq3B_DONl7uk', 'duration': '3s'},
#       {'placeId': 'ChIJqSLHI77Gt4kRwHtUFuQkO5w', 'duration': '12s'},
#       {'placeId': 'ChIJNSKQJL7Gt4kRyaJwNvt0qUA', 'duration': '10s'},
#       {'placeId': 'ChIJZzp9O77Gt4kR4-qG_4esrxY', 'duration': '8s'},
#       {'placeId': 'ChIJD6auPr7Gt4kRswWdgjI2TPM', 'duration': '7s'},
#       {'placeId': 'ChIJy80bOb7Gt4kRF_pJUps5trQ', 'duration': '11s'},
#       {'placeId': 'ChIJSXKHN77Gt4kRDnovAIkR9rw', 'duration': '16s'},
#       {'placeId': 'ChIJiUWfSb7Gt4kR_pOhBnABX6E', 'duration': '22s'},
#       {'placeId': 'ChIJUcWHSb7Gt4kRZV5V8-DHFuU', 'duration': '22s'}],
#      'distanceMeters': 958.1483850549561,
#      'travelMode': 'WALK',
#      'confidence': 1.0}}},
#   {'placeVisit': {'location': {'latitudeE7': 389807888,
#      'longitudeE7': -769405848,
#      'placeId': 'ChIJt6HxL77Gt4kRl4IGDUTDUYk',
#      'address': '4313 Knox Rd\nCollege Park, MD 20740\nUSA',
#      'name': '4313 Knox Rd',
#      'semanticType': 'TYPE_SEARCHED_ADDRESS',
#      'sourceInfo': {'deviceTag': -1787875010},
#      'locationConfidence': 57.89067,
#      'calibratedProbability': 40.750774},
#     'duration': {'startTimestamp': '2022-04-30T19:59:44.499Z',
#      'endTimestamp': '2022-04-30T23:45:48.903Z'},
#     'placeConfidence': 'MEDIUM_CONFIDENCE',
#     'centerLatE7': 389810709,
#     'centerLngE7': -769401822,
#     'visitConfidence': 89,
#     'otherCandidateLocations': [{'latitudeE7': 389802374,
#       'longitudeE7': -769401607,
#       'placeId': 'ChIJx8BDM77Gt4kRqDKea7BpRfE',
#       'address': '4330 Hartwick Rd\nCollege Park, MD 20740\nUSA',
#       'name': 'College Park Towers',
#       'locationConfidence': 25.636621,
#       'calibratedProbability': 18.046295},
#      {'latitudeE7': 389869183,
#       'longitudeE7': -769425543,
#       'placeId': 'ChIJq6qaPr3Gt4kRmtrkpd2LjtQ',
#       'address': 'College Park, MD 20742\nUSA',
#       'name': 'University of Maryland',
#       'locationConfidence': 6.6478267,
#       'calibratedProbability': 4.6795807},
#      {'latitudeE7': 389803817,
#       'longitudeE7': -769420640,
#       'placeId': 'ChIJBSMt2wLEt4kRWflFq9TC5TA',
#       'address': '4300 Hartwick Rd\nCollege Park, MD 20740\nUSA',
#       'name': 'Terrapin Row',
#       'locationConfidence': 4.488028,
#       'calibratedProbability': 3.1592417},
#      {'latitudeE7': 389803570,
#       'longitudeE7': -769389750,
#       'placeId': 'ChIJTX_4-77Gt4kRuQB-xqDhHIA',
#       'address': '7332 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': '7332 Baltimore Ave',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 2.3379219,
#       'calibratedProbability': 1.645725},
#      {'latitudeE7': 389807620,
#       'longitudeE7': -769406008,
#       'placeId': 'ChIJxVXxML7Gt4kREUHkaU36IeY',
#       'address': '4313 Knox Rd\nCollege Park, MD 20740\nUSA',
#       'name': 'College Park Towers Condos',
#       'locationConfidence': 1.5852243,
#       'calibratedProbability': 1.1158812}],
#     'editConfirmationStatus': 'NOT_CONFIRMED',
#     'locationConfidence': 46,
#     'placeVisitType': 'SINGLE_PLACE',
#     'placeVisitImportance': 'MAIN'}},
#   {'activitySegment': {'startLocation': {'latitudeE7': 389817136,
#      'longitudeE7': -769404169,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'endLocation': {'latitudeE7': 389961196,
#      'longitudeE7': -769283715,
#      'sourceInfo': {'deviceTag': -1787875010}},
#     'duration': {'startTimestamp': '2022-04-30T23:45:48.903Z',
#      'endTimestamp': '2022-04-30T23:52:56.976Z'},
#     'distance': 2035,
#     'activityType': 'IN_PASSENGER_VEHICLE',
#     'confidence': 'MEDIUM',
#     'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#       'probability': 63.1442129611969},
#      {'activityType': 'CYCLING', 'probability': 28.71362864971161},
#      {'activityType': 'WALKING', 'probability': 5.1100775599479675},
#      {'activityType': 'RUNNING', 'probability': 0.7508974988013506},
#      {'activityType': 'MOTORCYCLING', 'probability': 0.7456853985786438},
#      {'activityType': 'STILL', 'probability': 0.5950009915977716},
#      {'activityType': 'IN_BUS', 'probability': 0.5427928641438484},
#      {'activityType': 'SKIING', 'probability': 0.1213585608638823},
#      {'activityType': 'IN_TRAM', 'probability': 0.11277386220172048},
#      {'activityType': 'IN_SUBWAY', 'probability': 0.07156299543567002},
#      {'activityType': 'IN_FERRY', 'probability': 0.06478297291323543},
#      {'activityType': 'IN_TRAIN', 'probability': 0.019342136511113495},
#      {'activityType': 'SAILING', 'probability': 0.0070026224420871586},
#      {'activityType': 'FLYING', 'probability': 0.0008778420124144759},
#      {'activityType': 'IN_VEHICLE', 'probability': 1.5963920185768643e-07}],
#     'waypointPath': {'waypoints': [{'latE7': 389817657, 'lngE7': -769398345},
#       {'latE7': 389886779, 'lngE7': -769349670},
#       {'latE7': 389961204, 'lngE7': -769283752}],
#      'source': 'INFERRED',
#      'roadSegment': [{'placeId': 'ChIJrczsar7Gt4kRD4bFlyyPX-g',
#        'duration': '28s'},
#       {'placeId': 'ChIJORY8Qb7Gt4kR68Lc7UU9E94', 'duration': '1s'},
#       {'placeId': 'ChIJQ8COQ77Gt4kRCqZO846_oOk', 'duration': '3s'},
#       {'placeId': 'ChIJQ8COQ77Gt4kRA1khzSGa7C0', 'duration': '7s'},
#       {'placeId': 'ChIJZWqfXL7Gt4kRlS_cwffUmtM', 'duration': '5s'},
#       {'placeId': 'ChIJdRlzXL7Gt4kR3ExDuj8lBNw', 'duration': '4s'},
#       {'placeId': 'ChIJB3yzXr7Gt4kR9y8rgLeQoks', 'duration': '5s'},
#       {'placeId': 'ChIJM2F19r7Gt4kRzjv0xho3lDM', 'duration': '6s'},
#       {'placeId': 'ChIJM2F19r7Gt4kRQvZoBGVdBc0', 'duration': '13s'},
#       {'placeId': 'ChIJM_zZ877Gt4kRnBc2nOWthoI', 'duration': '4s'},
#       {'placeId': 'ChIJK1nNjL7Gt4kR8KjwUAiibrA', 'duration': '16s'},
#       {'placeId': 'ChIJ8ZiFhb7Gt4kR8tF7sK9D4u4', 'duration': '16s'},
#       {'placeId': 'ChIJ5450g77Gt4kRNTJATHsN1Uk', 'duration': '2s'},
#       {'placeId': 'ChIJMadJKLzGt4kRF11mZM89zfU', 'duration': '11s'},
#       {'placeId': 'ChIJE9JJMLzGt4kR2_fA5sjo3z4', 'duration': '10s'},
#       {'placeId': 'ChIJY4cTRrzGt4kRwHhzvLd_XYc', 'duration': '17s'},
#       {'placeId': 'ChIJ86EHW7zGt4kROfCVAo0EtmI', 'duration': '1s'},
#       {'placeId': 'ChIJ19fdW7zGt4kRMQV6ipVieWk', 'duration': '4s'},
#       {'placeId': 'ChIJ92O1WLzGt4kRkYp4UVaXdHM', 'duration': '7s'},
#       {'placeId': 'ChIJ-SRC9LzGt4kRGYmN_AeRKf4', 'duration': '8s'},
#       {'placeId': 'ChIJMx4D87zGt4kRrQfMr5kalmU', 'duration': '4s'},
#       {'placeId': 'ChIJ6R6-8rzGt4kRJ1SbIRywdyQ', 'duration': '3s'},
#       {'placeId': 'ChIJ8X-OlLzGt4kR36fT4Hf_TGs', 'duration': '11s'},
#       {'placeId': 'ChIJ8X-OlLzGt4kRPn2-owNiHeI', 'duration': '6s'},
#       {'placeId': 'ChIJwdKbu7zGt4kRzRggjHkj5Gg', 'duration': '2s'},
#       {'placeId': 'ChIJwdKbu7zGt4kRn3VgrtRk9_E', 'duration': '11s'},
#       {'placeId': 'ChIJBwTXr7zGt4kRJUGnNqqlKfc', 'duration': '5s'},
#       {'placeId': 'ChIJWUhMrLzGt4kRW5aFQSyYmXs', 'duration': '6s'},
#       {'placeId': 'ChIJ64NWU6PGt4kRhfH5kT8qf4k', 'duration': '3s'},
#       {'placeId': 'ChIJM1o2VKPGt4kRS2yTeYgY-3M', 'duration': '6s'},
#       {'placeId': 'ChIJIQPRV6PGt4kROUgyWlAthWI', 'duration': '6s'},
#       {'placeId': 'ChIJSRbIpqTGt4kRnVrNiQNM2GQ', 'duration': '15s'},
#       {'placeId': 'ChIJVca_mKTGt4kRYjwOmiZ42hA', 'duration': '3s'},
#       {'placeId': 'ChIJgQvAmKTGt4kRTt3uKAFwe-8', 'duration': '2s'},
#       {'placeId': 'ChIJjzJ8mqTGt4kRCm0rYLDM7xY', 'duration': '12s'},
#       {'placeId': 'ChIJ883ajqTGt4kRP9QWX9T64sY', 'duration': '8s'},
#       {'placeId': 'ChIJd47sYaTGt4kROMxS5nq31jY', 'duration': '6s'},
#       {'placeId': 'ChIJQ_sCZ6TGt4kRMVFoAOUwtyQ', 'duration': '10s'},
#       {'placeId': 'ChIJ-T4vaKTGt4kR4csLOyf6uYk', 'duration': '1s'},
#       {'placeId': 'ChIJ-T4vaKTGt4kR-2wy6pdXey8', 'duration': '2s'},
#       {'placeId': 'ChIJbzPxQaTGt4kRk0Zm1R3WXJA', 'duration': '3s'},
#       {'placeId': 'ChIJB_tMQKTGt4kRi1HprYUbYEc', 'duration': '1s'},
#       {'placeId': 'ChIJBXXnPqTGt4kR4CXMectGJxE', 'duration': '6s'},
#       {'placeId': 'ChIJBXXnPqTGt4kRK0wbu7JTb8c', 'duration': '3s'},
#       {'placeId': 'ChIJ15nDJKTGt4kRwY5PgVPH0bs', 'duration': '5s'},
#       {'placeId': 'ChIJKR_YJaTGt4kRZJ_4-RmSFbA', 'duration': '1s'},
#       {'placeId': 'ChIJKR_YJaTGt4kR7TjkDdbWGgQ', 'duration': '1s'},
#       {'placeId': 'ChIJ54VqJqTGt4kR68vpTnpad6Y', 'duration': '2s'},
#       {'placeId': 'ChIJgTLMJ6TGt4kR9_dEU_Jy5P4', 'duration': '2s'},
#       {'placeId': 'ChIJ1eP_J6TGt4kRCs5_1nga4gY', 'duration': '1s'},
#       {'placeId': 'ChIJUVexgqbGt4kREIow6lIg9I8', 'duration': '1s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRKCCI3Arn_O4', 'duration': '5s'},
#       {'placeId': 'ChIJx1Vqg6bGt4kRS-a6zVKChfQ', 'duration': '2s'},
#       {'placeId': 'ChIJBa6VhabGt4kRePoAESd3IRg', 'duration': '3s'},
#       {'placeId': 'ChIJNe4lj6bGt4kRScD5JZmGgP8', 'duration': '6s'},
#       {'placeId': 'ChIJUZgQi6bGt4kRFxuy0jpRl7k', 'duration': '7s'},
#       {'placeId': 'ChIJwykP9abGt4kR2ODPQTwsrN0', 'duration': '0s'},
#       {'placeId': 'ChIJU4699abGt4kRVn7TFocxO94', 'duration': '1s'},
#       {'placeId': 'ChIJF8YF9qbGt4kRquxOw6ChBes', 'duration': '2s'},
#       {'placeId': 'ChIJYx1uWKbGt4kRrPX9qySzPII', 'duration': '3s'},
#       {'placeId': 'ChIJATS7V6bGt4kRzlIqeckXWaw', 'duration': '2s'},
#       {'placeId': 'ChIJqeaLVqbGt4kRhr7UUSy6YP8', 'duration': '1s'},
#       {'placeId': 'ChIJf90-VKbGt4kRHLCV2Iv6vTA', 'duration': '2s'},
#       {'placeId': 'ChIJcYCiVKbGt4kRKoa90oiPDq8', 'duration': '1s'},
#       {'placeId': 'ChIJg3ymrKfGt4kR75chIooSP2A', 'duration': '1s'},
#       {'placeId': 'ChIJlaWPrKfGt4kRB-7vqm0N190', 'duration': '1s'},
#       {'placeId': 'ChIJRRc8rKfGt4kRpwC1yl5mNmE', 'duration': '2s'},
#       {'placeId': 'ChIJvf70rqfGt4kR1-YANS8RYVo', 'duration': '1s'},
#       {'placeId': 'ChIJYSiOr6fGt4kRv7iW0HUqRao', 'duration': '4s'},
#       {'placeId': 'ChIJYR60pKfGt4kRM8cL5m5kl7s', 'duration': '5s'},
#       {'placeId': 'ChIJoxD7vKfGt4kRsSeFFbRjXOM', 'duration': '3s'},
#       {'placeId': 'ChIJtT30vqfGt4kR4UzxPMxyEok', 'duration': '6s'},
#       {'placeId': 'ChIJbY9gwqfGt4kReGTzg_fIjLw', 'duration': '10s'},
#       {'placeId': 'ChIJbY9gwqfGt4kRlU_WO_tcBr0', 'duration': '5s'},
#       {'placeId': 'ChIJs5fp46fGt4kR4Eb5I215MEA', 'duration': '15s'},
#       {'placeId': 'ChIJ2RWPB6jGt4kRsJtdewnBSY0', 'duration': '8s'},
#       {'placeId': 'ChIJ9cMLBajGt4kRlVOm-MEW6Tk', 'duration': '7s'},
#       {'placeId': 'ChIJ7dSrIqjGt4kR_63lWB_SHdM', 'duration': '7s'}],
#      'distanceMeters': 2374.719375764879,
#      'travelMode': 'DRIVE',
#      'confidence': 0.9816886261614585},
#     'parkingEvent': {'location': {'latitudeE7': 389959990,
#       'longitudeE7': -769283710,
#       'accuracyMetres': 80},
#      'method': 'END_OF_ACTIVITY_SEGMENT',
#      'locationSource': 'FROM_RAW_LOCATION',
#      'timestamp': '2022-04-30T23:55:37.916Z'}}},
#   {'placeVisit': {'location': {'latitudeE7': 389959742,
#      'longitudeE7': -769284073,
#      'placeId': 'ChIJQdjJF6jGt4kRQlYiYDyaIfc',
#      'address': '4815 Ruatan St\nBerwyn Heights, MD 20740\nUSA',
#      'name': '4815 Ruatan St',
#      'sourceInfo': {'deviceTag': -1787875010},
#      'locationConfidence': 87.3129,
#      'calibratedProbability': 67.540344},
#     'duration': {'startTimestamp': '2022-04-30T23:52:56.976Z',
#      'endTimestamp': '2022-05-01T02:48:19.772Z'},
#     'placeConfidence': 'HIGH_CONFIDENCE',
#     'centerLatE7': 389960031,
#     'centerLngE7': -769283754,
#     'visitConfidence': 86,
#     'otherCandidateLocations': [{'latitudeE7': 389970110,
#       'longitudeE7': -769295860,
#       'placeId': 'ChIJS3IcqwLEt4kRUkUcD9beZyk',
#       'address': '4717 Tecumseh St\nBerwyn Heights, MD 20740\nUSA',
#       'name': '4717 Tecumseh St',
#       'semanticType': 'TYPE_SEARCHED_ADDRESS',
#       'locationConfidence': 6.707753,
#       'calibratedProbability': 5.1887407},
#      {'latitudeE7': 389961844,
#       'longitudeE7': -769288853,
#       'placeId': 'ChIJSb6cGqjGt4kRzVh1yP7m4Cg',
#       'address': 'Berwyn, 20740\nCollege Park, MD 20740\nUSA',
#       'name': 'USPS Collection Box',
#       'locationConfidence': 2.821555,
#       'calibratedProbability': 2.1825962},
#      {'latitudeE7': 389962961,
#       'longitudeE7': -769310713,
#       'placeId': 'ChIJiRm5EKPHt4kRIIfq2I-kSoE',
#       'address': '8601 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Lidl',
#       'locationConfidence': 1.1743939,
#       'calibratedProbability': 0.90844506},
#      {'latitudeE7': 389977228,
#       'longitudeE7': -769311012,
#       'placeId': 'ChIJRyU6aB3Et4kRSgSc7ow7eGc',
#       'address': '8801 Baltimore Ave\nCollege Park, MD 20740\nUSA',
#       'name': 'Universal Barber Shop',
#       'locationConfidence': 0.2304456,
#       'calibratedProbability': 0.17825975}],
#     'editConfirmationStatus': 'NOT_CONFIRMED',
#     'locationConfidence': 72,
#     'placeVisitType': 'SINGLE_PLACE',
#     'placeVisitImportance': 'MAIN'}}]}
